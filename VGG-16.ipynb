# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import (
    VGG16, ResNet50, InceptionV3, EfficientNetB0, DenseNet169
)
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten, Dense, Dropout, BatchNormalization, GlobalAveragePooling2D
from tensorflow.keras.callbacks import ReduceLROnPlateau

# 🔧 Enable Mac GPU acceleration if available
try:
    tf.config.experimental.list_physical_devices('GPU')
    print("✅ Mac GPU (M1/M2) Acceleration Enabled!")
except Exception as e:
    print("⚠️ GPU not available or not supported:", e)

# 🔧 CONFIG
 classes = ["vasc", "df", "akeic"]
backbone_name = "VGG16"  # Choose: VGG16, ResNet50, InceptionV3, EfficientNetB0, DenseNet169
img_size = (224, 224) if backbone_name != "InceptionV3" else (299, 299)
batch_size = 32
epochs = 100
num_classes = len(classes)

# 🔄 Load and preprocess image data
X, y = [], []
for label, folder in enumerate(classes):
    folder_path = os.path.join(data_dir, folder)
    for img_file in os.listdir(folder_path):
        img_path = os.path.join(folder_path, img_file)
        try:
            img = tf.keras.utils.load_img(img_path, target_size=img_size)
            img_array = tf.keras.utils.img_to_array(img)
            X.append(img_array)
            y.append(label)
        except Exception as e:
            print(f"Skipped {img_path}: {e}")

X = np.array(X)
y = np.array(y)

X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.2, stratify=y, random_state=42)

# 🔄 Data Augmentation
train_gen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20, width_shift_range=0.1, height_shift_range=0.1,
    shear_range=0.1, zoom_range=0.1, horizontal_flip=True
)
val_gen = ImageDataGenerator(rescale=1./255)

train_data = train_gen.flow(X_train, y_train, batch_size=batch_size)
val_data = val_gen.flow(X_val, y_val, batch_size=batch_size)

# 🔌 Load chosen model
def get_backbone_model(name, input_shape):
    base = None
    if name == "VGG16":
        base = VGG16(weights="imagenet", include_top=False, input_shape=input_shape)
    elif name == "ResNet50":
        base = ResNet50(weights="imagenet", include_top=False, input_shape=input_shape)
    elif name == "InceptionV3":
        base = InceptionV3(weights="imagenet", include_top=False, input_shape=input_shape)
    elif name == "EfficientNetB0":
        base = EfficientNetB0(weights="imagenet", include_top=False, input_shape=input_shape)
    elif name == "DenseNet169":
        base = DenseNet169(weights="imagenet", include_top=False, input_shape=input_shape)
    else:
        raise ValueError("Unknown model name!")

    for layer in base.layers:
        layer.trainable = False

    return base

# 🧠 Build the model
input_shape = img_size + (3,)
base_model = get_backbone_model(backbone_name, input_shape)

model = Sequential([
    base_model,
    GlobalAveragePooling2D(),
    Dense(256, activation='relu'),
    BatchNormalization(),
    Dropout(0.5),
    Dense(num_classes, activation='softmax')
])

model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

print(f"🧠 Training with: {backbone_name}")
model.summary()

# 🚀 Train
history = model.fit(
    train_data,
    validation_data=val_data,
    epochs=epochs,
    callbacks=[ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=3, min_lr=1e-6)],
    verbose=1
)

# 📊 Evaluate
val_loss, val_acc = model.evaluate(val_data)
print(f"\n✅ Final Val Loss: {val_loss:.4f} | Val Accuracy: {val_acc:.4f}")

# 📈 Plot Accuracy and Loss
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Acc')
plt.plot(history.history['val_accuracy'], label='Val Acc')
plt.title('Accuracy')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.title('Loss')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# ✅ Mac GPU (M1/M2) Acceleration Enabled!
# 2025-07-28 13:09:05.489706: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M3
# 2025-07-28 13:09:05.489762: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 16.00 GB
# 2025-07-28 13:09:05.489765: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 5.33 GB
# 2025-07-28 13:09:05.489785: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2025-07-28 13:09:05.489798: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# 🧠 Training with: VGG16
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ vgg16 (Functional)              │ (None, 7, 7, 512)      │    14,714,688 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 512)            │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 3)              │           771 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 14,847,811 (56.64 MB)
#  Trainable params: 132,611 (518.01 KB)
#  Non-trainable params: 14,715,200 (56.13 MB)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/100
# 2025-07-28 13:09:06.571978: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:117] Plugin optimizer for device_type GPU is enabled.
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 16s 368ms/step - accuracy: 0.4385 - loss: 1.5056 - val_accuracy: 0.5935 - val_loss: 1.0850 - learning_rate: 1.0000e-04
# Epoch 2/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 16s 385ms/step - accuracy: 0.5680 - loss: 1.1337 - val_accuracy: 0.6291 - val_loss: 1.0181 - learning_rate: 1.0000e-04
# Epoch 3/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 18s 422ms/step - accuracy: 0.6271 - loss: 0.9883 - val_accuracy: 0.6202 - val_loss: 0.9406 - learning_rate: 1.0000e-04
# Epoch 4/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 18s 420ms/step - accuracy: 0.6288 - loss: 0.9710 - val_accuracy: 0.6320 - val_loss: 0.8756 - learning_rate: 1.0000e-04
# Epoch 5/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 18s 436ms/step - accuracy: 0.6501 - loss: 0.9168 - val_accuracy: 0.6499 - val_loss: 0.8272 - learning_rate: 1.0000e-04
# Epoch 6/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 21s 505ms/step - accuracy: 0.6978 - loss: 0.8176 - val_accuracy: 0.7448 - val_loss: 0.7663 - learning_rate: 1.0000e-04
# Epoch 7/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 20s 469ms/step - accuracy: 0.6870 - loss: 0.7902 - val_accuracy: 0.7567 - val_loss: 0.7225 - learning_rate: 1.0000e-04
# Epoch 8/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 26s 622ms/step - accuracy: 0.6768 - loss: 0.8594 - val_accuracy: 0.7715 - val_loss: 0.6740 - learning_rate: 1.0000e-04
# Epoch 9/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 30s 717ms/step - accuracy: 0.6846 - loss: 0.7754 - val_accuracy: 0.7418 - val_loss: 0.6430 - learning_rate: 1.0000e-04
# Epoch 10/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 27s 652ms/step - accuracy: 0.6980 - loss: 0.7939 - val_accuracy: 0.7567 - val_loss: 0.6190 - learning_rate: 1.0000e-04
# Epoch 11/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 23s 545ms/step - accuracy: 0.6922 - loss: 0.8219 - val_accuracy: 0.7745 - val_loss: 0.5885 - learning_rate: 1.0000e-04
# Epoch 12/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 22s 531ms/step - accuracy: 0.7056 - loss: 0.7659 - val_accuracy: 0.7804 - val_loss: 0.5667 - learning_rate: 1.0000e-04
# Epoch 13/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 23s 537ms/step - accuracy: 0.6902 - loss: 0.8222 - val_accuracy: 0.7893 - val_loss: 0.5446 - learning_rate: 1.0000e-04
# Epoch 14/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 22s 535ms/step - accuracy: 0.6950 - loss: 0.7422 - val_accuracy: 0.7685 - val_loss: 0.5511 - learning_rate: 1.0000e-04
# Epoch 15/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 21s 501ms/step - accuracy: 0.7261 - loss: 0.6864 - val_accuracy: 0.7893 - val_loss: 0.5360 - learning_rate: 1.0000e-04
# Epoch 16/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 21s 510ms/step - accuracy: 0.7065 - loss: 0.7364 - val_accuracy: 0.7953 - val_loss: 0.5479 - learning_rate: 1.0000e-04
# Epoch 17/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 22s 511ms/step - accuracy: 0.7310 - loss: 0.6802 - val_accuracy: 0.8042 - val_loss: 0.5143 - learning_rate: 1.0000e-04
# Epoch 18/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 22s 519ms/step - accuracy: 0.7502 - loss: 0.6716 - val_accuracy: 0.7982 - val_loss: 0.5209 - learning_rate: 1.0000e-04
# Epoch 19/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 23s 559ms/step - accuracy: 0.7515 - loss: 0.6633 - val_accuracy: 0.7982 - val_loss: 0.5088 - learning_rate: 1.0000e-04
# Epoch 20/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 23s 554ms/step - accuracy: 0.7576 - loss: 0.6468 - val_accuracy: 0.8012 - val_loss: 0.4852 - learning_rate: 1.0000e-04
# Epoch 21/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 24s 567ms/step - accuracy: 0.7065 - loss: 0.7772 - val_accuracy: 0.7953 - val_loss: 0.5291 - learning_rate: 1.0000e-04
# Epoch 22/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 25s 590ms/step - accuracy: 0.7382 - loss: 0.7062 - val_accuracy: 0.8071 - val_loss: 0.5140 - learning_rate: 1.0000e-04
# Epoch 23/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 22s 533ms/step - accuracy: 0.7270 - loss: 0.6960 - val_accuracy: 0.8160 - val_loss: 0.4736 - learning_rate: 1.0000e-04
# Epoch 24/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 21s 510ms/step - accuracy: 0.7543 - loss: 0.6172 - val_accuracy: 0.8042 - val_loss: 0.4976 - learning_rate: 1.0000e-04
# Epoch 25/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 22s 517ms/step - accuracy: 0.7699 - loss: 0.6082 - val_accuracy: 0.8190 - val_loss: 0.4848 - learning_rate: 1.0000e-04
# Epoch 26/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 25s 588ms/step - accuracy: 0.7558 - loss: 0.6147 - val_accuracy: 0.8042 - val_loss: 0.4859 - learning_rate: 1.0000e-04
# Epoch 27/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 28s 666ms/step - accuracy: 0.7214 - loss: 0.6942 - val_accuracy: 0.8131 - val_loss: 0.4764 - learning_rate: 2.0000e-05
# Epoch 28/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 27s 643ms/step - accuracy: 0.7605 - loss: 0.6191 - val_accuracy: 0.8160 - val_loss: 0.4819 - learning_rate: 2.0000e-05
# Epoch 29/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 28s 676ms/step - accuracy: 0.7508 - loss: 0.6277 - val_accuracy: 0.8249 - val_loss: 0.4802 - learning_rate: 2.0000e-05
# Epoch 30/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 25s 602ms/step - accuracy: 0.7627 - loss: 0.6152 - val_accuracy: 0.8190 - val_loss: 0.4781 - learning_rate: 4.0000e-06
# Epoch 31/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 24s 562ms/step - accuracy: 0.7627 - loss: 0.6758 - val_accuracy: 0.8190 - val_loss: 0.4781 - learning_rate: 4.0000e-06
# Epoch 32/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 27s 639ms/step - accuracy: 0.7422 - loss: 0.6343 - val_accuracy: 0.8190 - val_loss: 0.4756 - learning_rate: 4.0000e-06
# Epoch 33/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 27s 648ms/step - accuracy: 0.7549 - loss: 0.6231 - val_accuracy: 0.8131 - val_loss: 0.4750 - learning_rate: 1.0000e-06
# Epoch 34/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 31s 736ms/step - accuracy: 0.7648 - loss: 0.6527 - val_accuracy: 0.8131 - val_loss: 0.4748 - learning_rate: 1.0000e-06
# Epoch 35/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 27s 652ms/step - accuracy: 0.7692 - loss: 0.5892 - val_accuracy: 0.8131 - val_loss: 0.4741 - learning_rate: 1.0000e-06
# Epoch 36/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 30s 721ms/step - accuracy: 0.7454 - loss: 0.6340 - val_accuracy: 0.8131 - val_loss: 0.4747 - learning_rate: 1.0000e-06
# Epoch 37/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 27s 644ms/step - accuracy: 0.7526 - loss: 0.6620 - val_accuracy: 0.8131 - val_loss: 0.4754 - learning_rate: 1.0000e-06
# Epoch 38/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 29s 697ms/step - accuracy: 0.7581 - loss: 0.6385 - val_accuracy: 0.8101 - val_loss: 0.4756 - learning_rate: 1.0000e-06
# Epoch 39/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 21s 507ms/step - accuracy: 0.7200 - loss: 0.7350 - val_accuracy: 0.8131 - val_loss: 0.4752 - learning_rate: 1.0000e-06
# Epoch 40/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 22s 533ms/step - accuracy: 0.7068 - loss: 0.6966 - val_accuracy: 0.8131 - val_loss: 0.4749 - learning_rate: 1.0000e-06
# Epoch 41/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 21s 511ms/step - accuracy: 0.7218 - loss: 0.6891 - val_accuracy: 0.8101 - val_loss: 0.4739 - learning_rate: 1.0000e-06
# Epoch 42/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 21s 501ms/step - accuracy: 0.7336 - loss: 0.6556 - val_accuracy: 0.8101 - val_loss: 0.4738 - learning_rate: 1.0000e-06
# Epoch 43/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 21s 503ms/step - accuracy: 0.7499 - loss: 0.6534 - val_accuracy: 0.8101 - val_loss: 0.4738 - learning_rate: 1.0000e-06
# Epoch 44/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 23s 547ms/step - accuracy: 0.7573 - loss: 0.6076 - val_accuracy: 0.8071 - val_loss: 0.4735 - learning_rate: 1.0000e-06
# Epoch 45/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 23s 552ms/step - accuracy: 0.7461 - loss: 0.6140 - val_accuracy: 0.8071 - val_loss: 0.4729 - learning_rate: 1.0000e-06
# Epoch 46/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 29s 694ms/step - accuracy: 0.7460 - loss: 0.6918 - val_accuracy: 0.8071 - val_loss: 0.4729 - learning_rate: 1.0000e-06
# Epoch 47/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 26s 628ms/step - accuracy: 0.7486 - loss: 0.6781 - val_accuracy: 0.8101 - val_loss: 0.4727 - learning_rate: 1.0000e-06
# Epoch 48/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 22s 529ms/step - accuracy: 0.7543 - loss: 0.6238 - val_accuracy: 0.8160 - val_loss: 0.4738 - learning_rate: 1.0000e-06
# Epoch 49/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 30s 717ms/step - accuracy: 0.7565 - loss: 0.6446 - val_accuracy: 0.8160 - val_loss: 0.4736 - learning_rate: 1.0000e-06
# Epoch 50/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 26s 613ms/step - accuracy: 0.7673 - loss: 0.6052 - val_accuracy: 0.8131 - val_loss: 0.4738 - learning_rate: 1.0000e-06
# Epoch 51/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 29s 682ms/step - accuracy: 0.7794 - loss: 0.5987 - val_accuracy: 0.8160 - val_loss: 0.4736 - learning_rate: 1.0000e-06
# Epoch 52/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 26s 608ms/step - accuracy: 0.7467 - loss: 0.6068 - val_accuracy: 0.8160 - val_loss: 0.4734 - learning_rate: 1.0000e-06
# Epoch 53/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 23s 538ms/step - accuracy: 0.7420 - loss: 0.6617 - val_accuracy: 0.8160 - val_loss: 0.4739 - learning_rate: 1.0000e-06
# Epoch 54/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 23s 553ms/step - accuracy: 0.7171 - loss: 0.6982 - val_accuracy: 0.8160 - val_loss: 0.4733 - learning_rate: 1.0000e-06
# Epoch 55/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 23s 542ms/step - accuracy: 0.7649 - loss: 0.6226 - val_accuracy: 0.8160 - val_loss: 0.4736 - learning_rate: 1.0000e-06
# Epoch 56/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 24s 560ms/step - accuracy: 0.7528 - loss: 0.6210 - val_accuracy: 0.8131 - val_loss: 0.4732 - learning_rate: 1.0000e-06
# Epoch 57/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 23s 551ms/step - accuracy: 0.7473 - loss: 0.6416 - val_accuracy: 0.8101 - val_loss: 0.4731 - learning_rate: 1.0000e-06
# Epoch 58/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 23s 553ms/step - accuracy: 0.7567 - loss: 0.6357 - val_accuracy: 0.8131 - val_loss: 0.4732 - learning_rate: 1.0000e-06
# Epoch 59/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 23s 547ms/step - accuracy: 0.7721 - loss: 0.6162 - val_accuracy: 0.8131 - val_loss: 0.4735 - learning_rate: 1.0000e-06
# Epoch 60/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 23s 555ms/step - accuracy: 0.7614 - loss: 0.6620 - val_accuracy: 0.8160 - val_loss: 0.4739 - learning_rate: 1.0000e-06
# Epoch 61/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 29s 703ms/step - accuracy: 0.7543 - loss: 0.6412 - val_accuracy: 0.8160 - val_loss: 0.4733 - learning_rate: 1.0000e-06
# Epoch 62/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 30s 730ms/step - accuracy: 0.7666 - loss: 0.6312 - val_accuracy: 0.8160 - val_loss: 0.4725 - learning_rate: 1.0000e-06
# Epoch 63/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 30s 710ms/step - accuracy: 0.7599 - loss: 0.6527 - val_accuracy: 0.8131 - val_loss: 0.4733 - learning_rate: 1.0000e-06
# Epoch 64/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 28s 671ms/step - accuracy: 0.7476 - loss: 0.6527 - val_accuracy: 0.8131 - val_loss: 0.4743 - learning_rate: 1.0000e-06
# Epoch 65/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 32s 767ms/step - accuracy: 0.7341 - loss: 0.6761 - val_accuracy: 0.8131 - val_loss: 0.4751 - learning_rate: 1.0000e-06
# Epoch 66/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 31s 749ms/step - accuracy: 0.7740 - loss: 0.5796 - val_accuracy: 0.8101 - val_loss: 0.4742 - learning_rate: 1.0000e-06
# Epoch 67/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 30s 714ms/step - accuracy: 0.7381 - loss: 0.6967 - val_accuracy: 0.8131 - val_loss: 0.4740 - learning_rate: 1.0000e-06
# Epoch 68/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 32s 772ms/step - accuracy: 0.7573 - loss: 0.6252 - val_accuracy: 0.8160 - val_loss: 0.4745 - learning_rate: 1.0000e-06
# Epoch 69/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 24s 560ms/step - accuracy: 0.7736 - loss: 0.5903 - val_accuracy: 0.8101 - val_loss: 0.4741 - learning_rate: 1.0000e-06
# Epoch 70/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 27s 636ms/step - accuracy: 0.7669 - loss: 0.6257 - val_accuracy: 0.8131 - val_loss: 0.4742 - learning_rate: 1.0000e-06
# Epoch 71/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 33s 779ms/step - accuracy: 0.7519 - loss: 0.6588 - val_accuracy: 0.8131 - val_loss: 0.4735 - learning_rate: 1.0000e-06
# Epoch 72/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 32s 758ms/step - accuracy: 0.7484 - loss: 0.6534 - val_accuracy: 0.8131 - val_loss: 0.4731 - learning_rate: 1.0000e-06
# Epoch 73/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 31s 737ms/step - accuracy: 0.7623 - loss: 0.6649 - val_accuracy: 0.8131 - val_loss: 0.4732 - learning_rate: 1.0000e-06
# Epoch 74/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 31s 731ms/step - accuracy: 0.7264 - loss: 0.6515 - val_accuracy: 0.8131 - val_loss: 0.4728 - learning_rate: 1.0000e-06
# Epoch 75/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 30s 726ms/step - accuracy: 0.7471 - loss: 0.6149 - val_accuracy: 0.8131 - val_loss: 0.4721 - learning_rate: 1.0000e-06
# Epoch 76/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 29s 699ms/step - accuracy: 0.7146 - loss: 0.6741 - val_accuracy: 0.8131 - val_loss: 0.4717 - learning_rate: 1.0000e-06
# Epoch 77/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 30s 729ms/step - accuracy: 0.7370 - loss: 0.6468 - val_accuracy: 0.8131 - val_loss: 0.4728 - learning_rate: 1.0000e-06
# Epoch 78/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 39s 944ms/step - accuracy: 0.7216 - loss: 0.7258 - val_accuracy: 0.8131 - val_loss: 0.4725 - learning_rate: 1.0000e-06
# Epoch 79/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 44s 1s/step - accuracy: 0.7538 - loss: 0.6373 - val_accuracy: 0.8131 - val_loss: 0.4726 - learning_rate: 1.0000e-06
# Epoch 80/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 38s 914ms/step - accuracy: 0.7640 - loss: 0.6483 - val_accuracy: 0.8131 - val_loss: 0.4733 - learning_rate: 1.0000e-06
# Epoch 81/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 39s 913ms/step - accuracy: 0.7271 - loss: 0.6776 - val_accuracy: 0.8131 - val_loss: 0.4726 - learning_rate: 1.0000e-06
# Epoch 82/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 52s 1s/step - accuracy: 0.7503 - loss: 0.6315 - val_accuracy: 0.8131 - val_loss: 0.4734 - learning_rate: 1.0000e-06
# Epoch 83/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 45s 1s/step - accuracy: 0.7472 - loss: 0.6993 - val_accuracy: 0.8131 - val_loss: 0.4726 - learning_rate: 1.0000e-06
# Epoch 84/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 40s 944ms/step - accuracy: 0.7308 - loss: 0.6833 - val_accuracy: 0.8131 - val_loss: 0.4726 - learning_rate: 1.0000e-06
# Epoch 85/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 36s 856ms/step - accuracy: 0.7641 - loss: 0.6322 - val_accuracy: 0.8131 - val_loss: 0.4729 - learning_rate: 1.0000e-06
# Epoch 86/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 36s 856ms/step - accuracy: 0.7391 - loss: 0.6268 - val_accuracy: 0.8131 - val_loss: 0.4728 - learning_rate: 1.0000e-06
# Epoch 87/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 31s 740ms/step - accuracy: 0.7661 - loss: 0.5875 - val_accuracy: 0.8131 - val_loss: 0.4721 - learning_rate: 1.0000e-06
# Epoch 88/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 39s 926ms/step - accuracy: 0.7605 - loss: 0.5728 - val_accuracy: 0.8131 - val_loss: 0.4727 - learning_rate: 1.0000e-06
# Epoch 89/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 36s 848ms/step - accuracy: 0.7534 - loss: 0.6056 - val_accuracy: 0.8131 - val_loss: 0.4724 - learning_rate: 1.0000e-06
# Epoch 90/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 44s 1s/step - accuracy: 0.7607 - loss: 0.5858 - val_accuracy: 0.8131 - val_loss: 0.4731 - learning_rate: 1.0000e-06
# Epoch 91/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 39s 915ms/step - accuracy: 0.7438 - loss: 0.6429 - val_accuracy: 0.8131 - val_loss: 0.4725 - learning_rate: 1.0000e-06
# Epoch 92/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 38s 902ms/step - accuracy: 0.7696 - loss: 0.5902 - val_accuracy: 0.8131 - val_loss: 0.4722 - learning_rate: 1.0000e-06
# Epoch 93/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 57s 1s/step - accuracy: 0.7518 - loss: 0.6560 - val_accuracy: 0.8131 - val_loss: 0.4726 - learning_rate: 1.0000e-06
# Epoch 94/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 75s 2s/step - accuracy: 0.7487 - loss: 0.6484 - val_accuracy: 0.8131 - val_loss: 0.4723 - learning_rate: 1.0000e-06
# Epoch 95/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 64s 2s/step - accuracy: 0.7691 - loss: 0.6310 - val_accuracy: 0.8131 - val_loss: 0.4722 - learning_rate: 1.0000e-06
# Epoch 96/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 51s 1s/step - accuracy: 0.7375 - loss: 0.6140 - val_accuracy: 0.8131 - val_loss: 0.4717 - learning_rate: 1.0000e-06
# Epoch 97/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 44s 1s/step - accuracy: 0.7267 - loss: 0.6848 - val_accuracy: 0.8101 - val_loss: 0.4704 - learning_rate: 1.0000e-06
# Epoch 98/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 45s 1s/step - accuracy: 0.7365 - loss: 0.6562 - val_accuracy: 0.8101 - val_loss: 0.4698 - learning_rate: 1.0000e-06
# Epoch 99/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 39s 939ms/step - accuracy: 0.7465 - loss: 0.6477 - val_accuracy: 0.8101 - val_loss: 0.4701 - learning_rate: 1.0000e-06
# Epoch 100/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 38s 916ms/step - accuracy: 0.7491 - loss: 0.6226 - val_accuracy: 0.8101 - val_loss: 0.4703 - learning_rate: 1.0000e-06
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 9s 747ms/step - accuracy: 0.8068 - loss: 0.4344
#
# ✅ Final Val Loss: 0.4703 | Val Accuracy: 0.8101
