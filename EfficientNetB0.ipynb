# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import (
    VGG16, ResNet50, InceptionV3, EfficientNetB0, DenseNet169
)
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten, Dense, Dropout, BatchNormalization, GlobalAveragePooling2D
from tensorflow.keras.callbacks import ReduceLROnPlateau

# 🔧 Enable Mac GPU acceleration if available
try:
    tf.config.experimental.list_physical_devices('GPU')
    print("✅ Mac GPU (M1/M2) Acceleration Enabled!")
except Exception as e:
    print("⚠️ GPU not available or not supported:", e)



data_dir = "/Users/amitabh/Documents/ML Work/Skin Cancer/v3/dataset"


# 🔧 CONFIG
classes = ["vasc", "df", "akeic"]
backbone_name = "EfficientNetB0"  # Choose: VGG16, ResNet50, InceptionV3, EfficientNetB0, DenseNet169
img_size = (224, 224) if backbone_name != "InceptionV3" else (299, 299)
batch_size = 32
epochs = 100
num_classes = len(classes)

# 🔄 Load and preprocess image data
X, y = [], []
for label, folder in enumerate(classes):
    folder_path = os.path.join(data_dir, folder)
    for img_file in os.listdir(folder_path):
        img_path = os.path.join(folder_path, img_file)
        try:
            img = tf.keras.utils.load_img(img_path, target_size=img_size)
            img_array = tf.keras.utils.img_to_array(img)
            X.append(img_array)
            y.append(label)
        except Exception as e:
            print(f"Skipped {img_path}: {e}")

X = np.array(X)
y = np.array(y)

X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.2, stratify=y, random_state=42)

# 🔄 Data Augmentation
train_gen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20, width_shift_range=0.1, height_shift_range=0.1,
    shear_range=0.1, zoom_range=0.1, horizontal_flip=True
)
val_gen = ImageDataGenerator(rescale=1./255)

train_data = train_gen.flow(X_train, y_train, batch_size=batch_size)
val_data = val_gen.flow(X_val, y_val, batch_size=batch_size)

# 🔌 Load chosen model
def get_backbone_model(name, input_shape):
    base = None
    if name == "VGG16":
        base = VGG16(weights="imagenet", include_top=False, input_shape=input_shape)
    elif name == "ResNet50":
        base = ResNet50(weights="imagenet", include_top=False, input_shape=input_shape)
    elif name == "InceptionV3":
        base = InceptionV3(weights="imagenet", include_top=False, input_shape=input_shape)
    elif name == "EfficientNetB0":
        base = EfficientNetB0(weights="imagenet", include_top=False, input_shape=input_shape)
    elif name == "DenseNet169":
        base = DenseNet169(weights="imagenet", include_top=False, input_shape=input_shape)
    else:
        raise ValueError("Unknown model name!")

    for layer in base.layers:
        layer.trainable = False

    return base

# 🧠 Build the model
input_shape = img_size + (3,)
base_model = get_backbone_model(backbone_name, input_shape)

model = Sequential([
    base_model,
    GlobalAveragePooling2D(),
    Dense(256, activation='relu'),
    BatchNormalization(),
    Dropout(0.5),
    Dense(num_classes, activation='softmax')
])

model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

print(f"🧠 Training with: {backbone_name}")
model.summary()

# 🚀 Train
history = model.fit(
    train_data,
    validation_data=val_data,
    epochs=epochs,
    callbacks=[ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=3, min_lr=1e-6)],
    verbose=1
)

# 📊 Evaluate
val_loss, val_acc = model.evaluate(val_data)
print(f"\n✅ Final Val Loss: {val_loss:.4f} | Val Accuracy: {val_acc:.4f}")

# 📈 Plot Accuracy and Loss
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Acc')
plt.plot(history.history['val_accuracy'], label='Val Acc')
plt.title('Accuracy')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.title('Loss')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# ✅ Mac GPU (M1/M2) Acceleration Enabled!
# 2025-07-28 17:04:47.025675: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M3
# 2025-07-28 17:04:47.027243: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 16.00 GB
# 2025-07-28 17:04:47.027248: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 5.33 GB
# 2025-07-28 17:04:47.028577: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2025-07-28 17:04:47.028607: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# 🧠 Training with: EfficientNetB0
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ efficientnetb0 (Functional)     │ (None, 7, 7, 1280)     │     4,049,571 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 1280)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │       327,936 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 3)              │           771 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 4,379,302 (16.71 MB)
#  Trainable params: 329,219 (1.26 MB)
#  Non-trainable params: 4,050,083 (15.45 MB)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/100
# 2025-07-28 17:04:51.918249: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:117] Plugin optimizer for device_type GPU is enabled.
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 21s 294ms/step - accuracy: 0.3514 - loss: 1.4558 - val_accuracy: 0.3561 - val_loss: 1.1185 - learning_rate: 1.0000e-04
# Epoch 2/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 11s 263ms/step - accuracy: 0.2989 - loss: 1.4705 - val_accuracy: 0.3561 - val_loss: 1.1100 - learning_rate: 1.0000e-04
# Epoch 3/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 13s 312ms/step - accuracy: 0.3529 - loss: 1.4076 - val_accuracy: 0.3145 - val_loss: 1.1084 - learning_rate: 1.0000e-04
# Epoch 4/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 28s 676ms/step - accuracy: 0.3304 - loss: 1.3492 - val_accuracy: 0.3145 - val_loss: 1.0999 - learning_rate: 1.0000e-04
# Epoch 5/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 84s 2s/step - accuracy: 0.3143 - loss: 1.3748 - val_accuracy: 0.3145 - val_loss: 1.1068 - learning_rate: 1.0000e-04
# Epoch 6/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 51s 1s/step - accuracy: 0.3259 - loss: 1.3564 - val_accuracy: 0.3561 - val_loss: 1.1144 - learning_rate: 1.0000e-04
# Epoch 7/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 46s 1s/step - accuracy: 0.3316 - loss: 1.4120 - val_accuracy: 0.3561 - val_loss: 1.1062 - learning_rate: 1.0000e-04
# Epoch 8/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 65s 2s/step - accuracy: 0.3316 - loss: 1.3322 - val_accuracy: 0.3561 - val_loss: 1.0992 - learning_rate: 2.0000e-05
# Epoch 9/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 36s 862ms/step - accuracy: 0.3333 - loss: 1.3573 - val_accuracy: 0.3294 - val_loss: 1.1160 - learning_rate: 2.0000e-05
# Epoch 10/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 28s 669ms/step - accuracy: 0.3467 - loss: 1.3400 - val_accuracy: 0.3858 - val_loss: 1.1010 - learning_rate: 2.0000e-05
# Epoch 11/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 31s 729ms/step - accuracy: 0.3065 - loss: 1.4037 - val_accuracy: 0.3145 - val_loss: 1.1002 - learning_rate: 2.0000e-05
# Epoch 12/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 24s 569ms/step - accuracy: 0.3502 - loss: 1.3135 - val_accuracy: 0.3561 - val_loss: 1.1010 - learning_rate: 4.0000e-06
# Epoch 13/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 43s 1s/step - accuracy: 0.3249 - loss: 1.3090 - val_accuracy: 0.3561 - val_loss: 1.1011 - learning_rate: 4.0000e-06
# Epoch 14/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 45s 1s/step - accuracy: 0.3386 - loss: 1.3173 - val_accuracy: 0.3591 - val_loss: 1.0985 - learning_rate: 4.0000e-06
# Epoch 15/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 44s 1s/step - accuracy: 0.3266 - loss: 1.4058 - val_accuracy: 0.3561 - val_loss: 1.0974 - learning_rate: 4.0000e-06
# Epoch 16/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 38s 913ms/step - accuracy: 0.3327 - loss: 1.3452 - val_accuracy: 0.3561 - val_loss: 1.1006 - learning_rate: 4.0000e-06
# Epoch 17/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 40s 957ms/step - accuracy: 0.3414 - loss: 1.3144 - val_accuracy: 0.3561 - val_loss: 1.1234 - learning_rate: 4.0000e-06
# Epoch 18/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 44s 1s/step - accuracy: 0.3647 - loss: 1.2828 - val_accuracy: 0.3561 - val_loss: 1.1040 - learning_rate: 4.0000e-06
# Epoch 19/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 43s 1s/step - accuracy: 0.3380 - loss: 1.3788 - val_accuracy: 0.3561 - val_loss: 1.1014 - learning_rate: 1.0000e-06
# Epoch 20/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 49s 1s/step - accuracy: 0.3464 - loss: 1.3197 - val_accuracy: 0.3561 - val_loss: 1.0979 - learning_rate: 1.0000e-06
# Epoch 21/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 43s 1s/step - accuracy: 0.3233 - loss: 1.3814 - val_accuracy: 0.3561 - val_loss: 1.1001 - learning_rate: 1.0000e-06
# Epoch 22/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 26s 621ms/step - accuracy: 0.3340 - loss: 1.3152 - val_accuracy: 0.3145 - val_loss: 1.1026 - learning_rate: 1.0000e-06
# Epoch 23/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 25s 587ms/step - accuracy: 0.3363 - loss: 1.3652 - val_accuracy: 0.3145 - val_loss: 1.1065 - learning_rate: 1.0000e-06
# Epoch 24/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 27s 636ms/step - accuracy: 0.3347 - loss: 1.3343 - val_accuracy: 0.3145 - val_loss: 1.1080 - learning_rate: 1.0000e-06
# Epoch 25/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 25s 595ms/step - accuracy: 0.3216 - loss: 1.3601 - val_accuracy: 0.3145 - val_loss: 1.1038 - learning_rate: 1.0000e-06
# Epoch 26/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 25s 590ms/step - accuracy: 0.3257 - loss: 1.3525 - val_accuracy: 0.3056 - val_loss: 1.1042 - learning_rate: 1.0000e-06
# Epoch 27/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 26s 624ms/step - accuracy: 0.3376 - loss: 1.3274 - val_accuracy: 0.3412 - val_loss: 1.1032 - learning_rate: 1.0000e-06
# Epoch 28/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 28s 659ms/step - accuracy: 0.3352 - loss: 1.3610 - val_accuracy: 0.3145 - val_loss: 1.1084 - learning_rate: 1.0000e-06
# Epoch 29/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 40s 951ms/step - accuracy: 0.3484 - loss: 1.3642 - val_accuracy: 0.3145 - val_loss: 1.1032 - learning_rate: 1.0000e-06
# Epoch 30/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 22s 528ms/step - accuracy: 0.3404 - loss: 1.3405 - val_accuracy: 0.3501 - val_loss: 1.0981 - learning_rate: 1.0000e-06
# Epoch 31/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 45s 1s/step - accuracy: 0.3461 - loss: 1.3547 - val_accuracy: 0.3650 - val_loss: 1.0993 - learning_rate: 1.0000e-06
# Epoch 32/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 55s 1s/step - accuracy: 0.3471 - loss: 1.3992 - val_accuracy: 0.3145 - val_loss: 1.1018 - learning_rate: 1.0000e-06
# Epoch 33/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 40s 950ms/step - accuracy: 0.3363 - loss: 1.3456 - val_accuracy: 0.3145 - val_loss: 1.1006 - learning_rate: 1.0000e-06
# Epoch 34/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 52s 1s/step - accuracy: 0.3292 - loss: 1.3576 - val_accuracy: 0.3383 - val_loss: 1.0991 - learning_rate: 1.0000e-06
# Epoch 35/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 52s 1s/step - accuracy: 0.3155 - loss: 1.4307 - val_accuracy: 0.3175 - val_loss: 1.1000 - learning_rate: 1.0000e-06
# Epoch 36/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 49s 1s/step - accuracy: 0.3340 - loss: 1.3528 - val_accuracy: 0.3175 - val_loss: 1.1015 - learning_rate: 1.0000e-06
# Epoch 37/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 51s 1s/step - accuracy: 0.3375 - loss: 1.3230 - val_accuracy: 0.3442 - val_loss: 1.0975 - learning_rate: 1.0000e-06
# Epoch 38/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 59s 1s/step - accuracy: 0.3426 - loss: 1.3130 - val_accuracy: 0.3591 - val_loss: 1.0982 - learning_rate: 1.0000e-06
# Epoch 39/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 60s 1s/step - accuracy: 0.3429 - loss: 1.3397 - val_accuracy: 0.3145 - val_loss: 1.1014 - learning_rate: 1.0000e-06
# Epoch 40/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 40s 944ms/step - accuracy: 0.3316 - loss: 1.3585 - val_accuracy: 0.3145 - val_loss: 1.1058 - learning_rate: 1.0000e-06
# Epoch 41/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 25s 589ms/step - accuracy: 0.3542 - loss: 1.2999 - val_accuracy: 0.3145 - val_loss: 1.1077 - learning_rate: 1.0000e-06
# Epoch 42/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 46s 1s/step - accuracy: 0.3251 - loss: 1.2744 - val_accuracy: 0.3264 - val_loss: 1.1005 - learning_rate: 1.0000e-06
# Epoch 43/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 22s 524ms/step - accuracy: 0.3263 - loss: 1.4025 - val_accuracy: 0.3145 - val_loss: 1.1006 - learning_rate: 1.0000e-06
# Epoch 44/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 23s 557ms/step - accuracy: 0.3224 - loss: 1.3655 - val_accuracy: 0.3561 - val_loss: 1.0985 - learning_rate: 1.0000e-06
# Epoch 45/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 24s 561ms/step - accuracy: 0.3548 - loss: 1.3238 - val_accuracy: 0.3561 - val_loss: 1.0974 - learning_rate: 1.0000e-06
# Epoch 46/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 28s 678ms/step - accuracy: 0.3541 - loss: 1.3257 - val_accuracy: 0.3561 - val_loss: 1.0990 - learning_rate: 1.0000e-06
# Epoch 47/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 36s 867ms/step - accuracy: 0.3273 - loss: 1.3129 - val_accuracy: 0.3561 - val_loss: 1.0970 - learning_rate: 1.0000e-06
# Epoch 48/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 66s 2s/step - accuracy: 0.3660 - loss: 1.2798 - val_accuracy: 0.3294 - val_loss: 1.0983 - learning_rate: 1.0000e-06
# Epoch 49/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 46s 1s/step - accuracy: 0.3225 - loss: 1.3466 - val_accuracy: 0.3294 - val_loss: 1.0990 - learning_rate: 1.0000e-06
# Epoch 50/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 53s 1s/step - accuracy: 0.3487 - loss: 1.3015 - val_accuracy: 0.3205 - val_loss: 1.0987 - learning_rate: 1.0000e-06
# Epoch 51/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 64s 2s/step - accuracy: 0.3323 - loss: 1.3164 - val_accuracy: 0.3116 - val_loss: 1.0986 - learning_rate: 1.0000e-06
# Epoch 52/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 79s 2s/step - accuracy: 0.3455 - loss: 1.3138 - val_accuracy: 0.3620 - val_loss: 1.0982 - learning_rate: 1.0000e-06
# Epoch 53/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 64s 2s/step - accuracy: 0.3278 - loss: 1.3271 - val_accuracy: 0.3798 - val_loss: 1.0974 - learning_rate: 1.0000e-06
# Epoch 54/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 51s 1s/step - accuracy: 0.3477 - loss: 1.3466 - val_accuracy: 0.3561 - val_loss: 1.0972 - learning_rate: 1.0000e-06
# Epoch 55/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 24s 578ms/step - accuracy: 0.3600 - loss: 1.2999 - val_accuracy: 0.3650 - val_loss: 1.0986 - learning_rate: 1.0000e-06
# Epoch 56/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 28s 674ms/step - accuracy: 0.3367 - loss: 1.3027 - val_accuracy: 0.3175 - val_loss: 1.1002 - learning_rate: 1.0000e-06
# Epoch 57/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 48s 1s/step - accuracy: 0.3396 - loss: 1.3399 - val_accuracy: 0.3145 - val_loss: 1.1031 - learning_rate: 1.0000e-06
# Epoch 58/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 52s 1s/step - accuracy: 0.3403 - loss: 1.3973 - val_accuracy: 0.3145 - val_loss: 1.1034 - learning_rate: 1.0000e-06
# Epoch 59/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 43s 1s/step - accuracy: 0.3494 - loss: 1.2906 - val_accuracy: 0.3145 - val_loss: 1.1038 - learning_rate: 1.0000e-06
# Epoch 60/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 43s 1s/step - accuracy: 0.3415 - loss: 1.3369 - val_accuracy: 0.3234 - val_loss: 1.1039 - learning_rate: 1.0000e-06
# Epoch 61/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 41s 973ms/step - accuracy: 0.3087 - loss: 1.3527 - val_accuracy: 0.3234 - val_loss: 1.1057 - learning_rate: 1.0000e-06
# Epoch 62/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 42s 1s/step - accuracy: 0.3338 - loss: 1.3604 - val_accuracy: 0.3561 - val_loss: 1.1041 - learning_rate: 1.0000e-06
# Epoch 63/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 36s 854ms/step - accuracy: 0.3333 - loss: 1.3159 - val_accuracy: 0.3561 - val_loss: 1.0989 - learning_rate: 1.0000e-06
# Epoch 64/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 60s 1s/step - accuracy: 0.3276 - loss: 1.3815 - val_accuracy: 0.3561 - val_loss: 1.1017 - learning_rate: 1.0000e-06
# Epoch 65/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 53s 1s/step - accuracy: 0.3667 - loss: 1.3212 - val_accuracy: 0.3561 - val_loss: 1.1009 - learning_rate: 1.0000e-06
# Epoch 66/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 47s 1s/step - accuracy: 0.3378 - loss: 1.3047 - val_accuracy: 0.3561 - val_loss: 1.0975 - learning_rate: 1.0000e-06
# Epoch 67/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 51s 1s/step - accuracy: 0.3171 - loss: 1.3531 - val_accuracy: 0.3531 - val_loss: 1.0970 - learning_rate: 1.0000e-06
# Epoch 68/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 37s 877ms/step - accuracy: 0.3448 - loss: 1.3239 - val_accuracy: 0.3561 - val_loss: 1.0978 - learning_rate: 1.0000e-06
# Epoch 69/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 19s 453ms/step - accuracy: 0.3363 - loss: 1.3789 - val_accuracy: 0.3531 - val_loss: 1.0986 - learning_rate: 1.0000e-06
# Epoch 70/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 31s 730ms/step - accuracy: 0.3327 - loss: 1.3168 - val_accuracy: 0.3145 - val_loss: 1.1022 - learning_rate: 1.0000e-06
# Epoch 71/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 35s 844ms/step - accuracy: 0.3396 - loss: 1.3617 - val_accuracy: 0.3027 - val_loss: 1.1026 - learning_rate: 1.0000e-06
# Epoch 72/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 39s 934ms/step - accuracy: 0.3434 - loss: 1.3177 - val_accuracy: 0.3294 - val_loss: 1.1032 - learning_rate: 1.0000e-06
# Epoch 73/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 39s 941ms/step - accuracy: 0.3397 - loss: 1.3339 - val_accuracy: 0.3531 - val_loss: 1.0991 - learning_rate: 1.0000e-06
# Epoch 74/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 37s 891ms/step - accuracy: 0.3419 - loss: 1.3304 - val_accuracy: 0.3709 - val_loss: 1.0983 - learning_rate: 1.0000e-06
# Epoch 75/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 21s 499ms/step - accuracy: 0.3244 - loss: 1.3308 - val_accuracy: 0.3680 - val_loss: 1.0984 - learning_rate: 1.0000e-06
# Epoch 76/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 21s 495ms/step - accuracy: 0.3284 - loss: 1.3428 - val_accuracy: 0.3175 - val_loss: 1.0998 - learning_rate: 1.0000e-06
# Epoch 77/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 23s 541ms/step - accuracy: 0.3586 - loss: 1.3088 - val_accuracy: 0.3323 - val_loss: 1.0979 - learning_rate: 1.0000e-06
# Epoch 78/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 39s 903ms/step - accuracy: 0.3342 - loss: 1.3304 - val_accuracy: 0.3264 - val_loss: 1.0985 - learning_rate: 1.0000e-06
# Epoch 79/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 40s 946ms/step - accuracy: 0.3332 - loss: 1.3325 - val_accuracy: 0.3264 - val_loss: 1.0981 - learning_rate: 1.0000e-06
# Epoch 80/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 35s 815ms/step - accuracy: 0.3352 - loss: 1.3355 - val_accuracy: 0.3294 - val_loss: 1.1004 - learning_rate: 1.0000e-06
# Epoch 81/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 21s 497ms/step - accuracy: 0.3325 - loss: 1.3545 - val_accuracy: 0.3294 - val_loss: 1.1003 - learning_rate: 1.0000e-06
# Epoch 82/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 20s 478ms/step - accuracy: 0.3319 - loss: 1.3304 - val_accuracy: 0.3264 - val_loss: 1.1001 - learning_rate: 1.0000e-06
# Epoch 83/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 20s 469ms/step - accuracy: 0.3347 - loss: 1.3250 - val_accuracy: 0.3858 - val_loss: 1.0976 - learning_rate: 1.0000e-06
# Epoch 84/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 35s 849ms/step - accuracy: 0.3338 - loss: 1.3173 - val_accuracy: 0.3561 - val_loss: 1.0974 - learning_rate: 1.0000e-06
# Epoch 85/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 34s 823ms/step - accuracy: 0.3263 - loss: 1.3254 - val_accuracy: 0.3680 - val_loss: 1.0974 - learning_rate: 1.0000e-06
# Epoch 86/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 32s 756ms/step - accuracy: 0.3513 - loss: 1.2879 - val_accuracy: 0.3323 - val_loss: 1.0995 - learning_rate: 1.0000e-06
# Epoch 87/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 46s 1s/step - accuracy: 0.3218 - loss: 1.3504 - val_accuracy: 0.3561 - val_loss: 1.0990 - learning_rate: 1.0000e-06
# Epoch 88/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 40s 955ms/step - accuracy: 0.3282 - loss: 1.3054 - val_accuracy: 0.3561 - val_loss: 1.0983 - learning_rate: 1.0000e-06
# Epoch 89/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 37s 894ms/step - accuracy: 0.3588 - loss: 1.2936 - val_accuracy: 0.3442 - val_loss: 1.0976 - learning_rate: 1.0000e-06
# Epoch 90/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 40s 956ms/step - accuracy: 0.3556 - loss: 1.3677 - val_accuracy: 0.3680 - val_loss: 1.0987 - learning_rate: 1.0000e-06
# Epoch 91/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 38s 921ms/step - accuracy: 0.3396 - loss: 1.3287 - val_accuracy: 0.3145 - val_loss: 1.1005 - learning_rate: 1.0000e-06
# Epoch 92/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 38s 914ms/step - accuracy: 0.3096 - loss: 1.3644 - val_accuracy: 0.3709 - val_loss: 1.0984 - learning_rate: 1.0000e-06
# Epoch 93/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 37s 873ms/step - accuracy: 0.3440 - loss: 1.3259 - val_accuracy: 0.3145 - val_loss: 1.1018 - learning_rate: 1.0000e-06
# Epoch 94/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 34s 806ms/step - accuracy: 0.3242 - loss: 1.3400 - val_accuracy: 0.3680 - val_loss: 1.0979 - learning_rate: 1.0000e-06
# Epoch 95/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 41s 975ms/step - accuracy: 0.3088 - loss: 1.3789 - val_accuracy: 0.3501 - val_loss: 1.0975 - learning_rate: 1.0000e-06
# Epoch 96/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 35s 829ms/step - accuracy: 0.3309 - loss: 1.3638 - val_accuracy: 0.3561 - val_loss: 1.0973 - learning_rate: 1.0000e-06
# Epoch 97/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 54s 1s/step - accuracy: 0.3271 - loss: 1.3794 - val_accuracy: 0.3531 - val_loss: 1.0980 - learning_rate: 1.0000e-06
# Epoch 98/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 34s 815ms/step - accuracy: 0.3539 - loss: 1.3024 - val_accuracy: 0.3561 - val_loss: 1.0980 - learning_rate: 1.0000e-06
# Epoch 99/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 47s 1s/step - accuracy: 0.3291 - loss: 1.3519 - val_accuracy: 0.3561 - val_loss: 1.0982 - learning_rate: 1.0000e-06
# Epoch 100/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 46s 1s/step - accuracy: 0.3199 - loss: 1.3537 - val_accuracy: 0.3501 - val_loss: 1.1022 - learning_rate: 1.0000e-06
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 6s 524ms/step - accuracy: 0.3554 - loss: 1.1048
#
# ✅ Final Val Loss: 1.1022 | Val Accuracy: 0.3501
