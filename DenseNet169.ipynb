# %%
! pip install tensorflow-macos
! pip install tensorflow-metal
# Out:
# Collecting tensorflow-macos
#   Using cached tensorflow_macos-2.16.2-cp310-cp310-macosx_12_0_arm64.whl.metadata (3.3 kB)
# Collecting tensorflow==2.16.2 (from tensorflow-macos)
#   Using cached tensorflow-2.16.2-cp310-cp310-macosx_12_0_arm64.whl.metadata (4.1 kB)
# Requirement already satisfied: absl-py>=1.0.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from tensorflow==2.16.2->tensorflow-macos) (2.2.0)
# Requirement already satisfied: astunparse>=1.6.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from tensorflow==2.16.2->tensorflow-macos) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from tensorflow==2.16.2->tensorflow-macos) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from tensorflow==2.16.2->tensorflow-macos) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from tensorflow==2.16.2->tensorflow-macos) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from tensorflow==2.16.2->tensorflow-macos) (3.13.0)
# Requirement already satisfied: libclang>=13.0.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from tensorflow==2.16.2->tensorflow-macos) (18.1.1)
# Collecting ml-dtypes~=0.3.1 (from tensorflow==2.16.2->tensorflow-macos)
#   Using cached ml_dtypes-0.3.2-cp310-cp310-macosx_10_9_universal2.whl.metadata (20 kB)
# Requirement already satisfied: opt-einsum>=2.3.2 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from tensorflow==2.16.2->tensorflow-macos) (3.4.0)
# Requirement already satisfied: packaging in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from tensorflow==2.16.2->tensorflow-macos) (24.2)
# Collecting protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 (from tensorflow==2.16.2->tensorflow-macos)
#   Using cached protobuf-4.25.8-cp37-abi3-macosx_10_9_universal2.whl.metadata (541 bytes)
# Requirement already satisfied: requests<3,>=2.21.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from tensorflow==2.16.2->tensorflow-macos) (2.32.3)
# Requirement already satisfied: setuptools in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from tensorflow==2.16.2->tensorflow-macos) (58.1.0)
# Requirement already satisfied: six>=1.12.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from tensorflow==2.16.2->tensorflow-macos) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from tensorflow==2.16.2->tensorflow-macos) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from tensorflow==2.16.2->tensorflow-macos) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from tensorflow==2.16.2->tensorflow-macos) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from tensorflow==2.16.2->tensorflow-macos) (1.70.0)
# Collecting tensorboard<2.17,>=2.16 (from tensorflow==2.16.2->tensorflow-macos)
#   Using cached tensorboard-2.16.2-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: keras>=3.0.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from tensorflow==2.16.2->tensorflow-macos) (3.9.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from tensorflow==2.16.2->tensorflow-macos) (0.37.1)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from tensorflow==2.16.2->tensorflow-macos) (1.24.4)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from astunparse>=1.6.0->tensorflow==2.16.2->tensorflow-macos) (0.45.1)
# Requirement already satisfied: rich in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from keras>=3.0.0->tensorflow==2.16.2->tensorflow-macos) (13.9.4)
# Requirement already satisfied: namex in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from keras>=3.0.0->tensorflow==2.16.2->tensorflow-macos) (0.0.8)
# Requirement already satisfied: optree in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from keras>=3.0.0->tensorflow==2.16.2->tensorflow-macos) (0.14.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorflow==2.16.2->tensorflow-macos) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorflow==2.16.2->tensorflow-macos) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorflow==2.16.2->tensorflow-macos) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorflow==2.16.2->tensorflow-macos) (2025.1.31)
# Requirement already satisfied: markdown>=2.6.8 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from tensorboard<2.17,>=2.16->tensorflow==2.16.2->tensorflow-macos) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from tensorboard<2.17,>=2.16->tensorflow==2.16.2->tensorflow-macos) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from tensorboard<2.17,>=2.16->tensorflow==2.16.2->tensorflow-macos) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from werkzeug>=1.0.1->tensorboard<2.17,>=2.16->tensorflow==2.16.2->tensorflow-macos) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from rich->keras>=3.0.0->tensorflow==2.16.2->tensorflow-macos) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from rich->keras>=3.0.0->tensorflow==2.16.2->tensorflow-macos) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.0.0->tensorflow==2.16.2->tensorflow-macos) (0.1.2)
# Using cached tensorflow_macos-2.16.2-cp310-cp310-macosx_12_0_arm64.whl (2.1 kB)
# Downloading tensorflow-2.16.2-cp310-cp310-macosx_12_0_arm64.whl (227.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 227.0/227.0 MB 2.7 MB/s eta 0:00:0000:0100:03m
# Downloading ml_dtypes-0.3.2-cp310-cp310-macosx_10_9_universal2.whl (389 kB)
# Downloading protobuf-4.25.8-cp37-abi3-macosx_10_9_universal2.whl (394 kB)
# Downloading tensorboard-2.16.2-py3-none-any.whl (5.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 12.1 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: protobuf, ml-dtypes, tensorboard, tensorflow, tensorflow-macos
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 5.29.4
#     Uninstalling protobuf-5.29.4:
#       Successfully uninstalled protobuf-5.29.4
#   Attempting uninstall: ml-dtypes
#     Found existing installation: ml_dtypes 0.5.1
#     Uninstalling ml_dtypes-0.5.1:
#       Successfully uninstalled ml_dtypes-0.5.1
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.19.0
#     Uninstalling tensorboard-2.19.0:
#       Successfully uninstalled tensorboard-2.19.0
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.19.0
#     Uninstalling tensorflow-2.19.0:
#       Successfully uninstalled tensorflow-2.19.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# grpcio-status 1.70.0 requires protobuf<6.0dev,>=5.26.1, but you have protobuf 4.25.8 which is incompatible.
# streamlit 1.22.0 requires protobuf<4,>=3.12, but you have protobuf 4.25.8 which is incompatible.
# tf-keras 2.19.0 requires tensorflow<2.20,>=2.19, but you have tensorflow 2.16.2 which is incompatible.
# Successfully installed ml-dtypes-0.3.2 protobuf-4.25.8 tensorboard-2.16.2 tensorflow-2.16.2 tensorflow-macos-2.16.2
#
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: tensorflow-metal in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (1.2.0)
# Requirement already satisfied: wheel~=0.35 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from tensorflow-metal) (0.45.1)
# Requirement already satisfied: six>=1.15.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from tensorflow-metal) (1.17.0)
#
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: pip install --upgrade pip

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import (
    VGG16, ResNet50, InceptionV3, EfficientNetB0, DenseNet169
)
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten, Dense, Dropout, BatchNormalization, GlobalAveragePooling2D
from tensorflow.keras.callbacks import ReduceLROnPlateau

# 🔧 Enable Mac GPU acceleration if available
try:
    tf.config.experimental.list_physical_devices('GPU')
    print("✅ Mac GPU (M1/M2) Acceleration Enabled!")
except Exception as e:
    print("⚠️ GPU not available or not supported:", e)

# 🔧 CONFIG
data_dir = "/Users/amitabh/Documents/ML Work/Skin Cancer/v3/dataset"
classes = ["vasc", "df", "akeic"]
backbone_name = "DenseNet169"  # Choose: VGG16, ResNet50, InceptionV3, EfficientNetB0, DenseNet169
img_size = (224, 224) if backbone_name != "InceptionV3" else (299, 299)
batch_size = 32
epochs = 100
num_classes = len(classes)

# 🔄 Load and preprocess image data
X, y = [], []
for label, folder in enumerate(classes):
    folder_path = os.path.join(data_dir, folder)
    for img_file in os.listdir(folder_path):
        img_path = os.path.join(folder_path, img_file)
        try:
            img = tf.keras.utils.load_img(img_path, target_size=img_size)
            img_array = tf.keras.utils.img_to_array(img)
            X.append(img_array)
            y.append(label)
        except Exception as e:
            print(f"Skipped {img_path}: {e}")

X = np.array(X)
y = np.array(y)

X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.2, stratify=y, random_state=42)

# 🔄 Data Augmentation
train_gen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20, width_shift_range=0.1, height_shift_range=0.1,
    shear_range=0.1, zoom_range=0.1, horizontal_flip=True
)
val_gen = ImageDataGenerator(rescale=1./255)

train_data = train_gen.flow(X_train, y_train, batch_size=batch_size)
val_data = val_gen.flow(X_val, y_val, batch_size=batch_size)

# 🔌 Load chosen model
def get_backbone_model(name, input_shape):
    base = None
    if name == "VGG16":
        base = VGG16(weights="imagenet", include_top=False, input_shape=input_shape)
    elif name == "ResNet50":
        base = ResNet50(weights="imagenet", include_top=False, input_shape=input_shape)
    elif name == "InceptionV3":
        base = InceptionV3(weights="imagenet", include_top=False, input_shape=input_shape)
    elif name == "EfficientNetB0":
        base = EfficientNetB0(weights="imagenet", include_top=False, input_shape=input_shape)
    elif name == "DenseNet169":
        base = DenseNet169(weights="imagenet", include_top=False, input_shape=input_shape)
    else:
        raise ValueError("Unknown model name!")

    for layer in base.layers:
        layer.trainable = False

    return base

# 🧠 Build the model
input_shape = img_size + (3,)
base_model = get_backbone_model(backbone_name, input_shape)

model = Sequential([
    base_model,
    GlobalAveragePooling2D(),
    Dense(256, activation='relu'),
    BatchNormalization(),
    Dropout(0.5),
    Dense(num_classes, activation='softmax')
])

model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

print(f"🧠 Training with: {backbone_name}")
model.summary()

# 🚀 Train
history = model.fit(
    train_data,
    validation_data=val_data,
    epochs=epochs,
    callbacks=[ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=3, min_lr=1e-6)],
    verbose=1
)

# 📊 Evaluate
val_loss, val_acc = model.evaluate(val_data)
print(f"\n✅ Final Val Loss: {val_loss:.4f} | Val Accuracy: {val_acc:.4f}")

# 📈 Plot Accuracy and Loss
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Acc')
plt.plot(history.history['val_accuracy'], label='Val Acc')
plt.title('Accuracy')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.title('Loss')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# ✅ Mac GPU (M1/M2) Acceleration Enabled!
# 2025-07-28 13:59:51.411654: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M3
# 2025-07-28 13:59:51.411712: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 16.00 GB
# 2025-07-28 13:59:51.411715: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 5.33 GB
# 2025-07-28 13:59:51.411729: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2025-07-28 13:59:51.411737: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# 🧠 Training with: DenseNet169
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ densenet169 (Functional)        │ (None, 7, 7, 1664)     │    12,642,880 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 1664)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │       426,240 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 3)              │           771 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 13,070,915 (49.86 MB)
#  Trainable params: 427,523 (1.63 MB)
#  Non-trainable params: 12,643,392 (48.23 MB)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/100
# 2025-07-28 13:59:56.762091: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:117] Plugin optimizer for device_type GPU is enabled.
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 37s 609ms/step - accuracy: 0.4549 - loss: 1.6803 - val_accuracy: 0.6884 - val_loss: 0.7436 - learning_rate: 1.0000e-04
# Epoch 2/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 18s 427ms/step - accuracy: 0.6499 - loss: 0.9695 - val_accuracy: 0.7062 - val_loss: 0.6595 - learning_rate: 1.0000e-04
# Epoch 3/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 18s 430ms/step - accuracy: 0.6968 - loss: 0.8695 - val_accuracy: 0.7626 - val_loss: 0.5906 - learning_rate: 1.0000e-04
# Epoch 4/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 79s 2s/step - accuracy: 0.7218 - loss: 0.7539 - val_accuracy: 0.7656 - val_loss: 0.5251 - learning_rate: 1.0000e-04
# Epoch 5/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 44s 1s/step - accuracy: 0.7396 - loss: 0.6820 - val_accuracy: 0.7923 - val_loss: 0.4833 - learning_rate: 1.0000e-04
# Epoch 6/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 30s 706ms/step - accuracy: 0.7757 - loss: 0.6325 - val_accuracy: 0.7982 - val_loss: 0.4560 - learning_rate: 1.0000e-04
# Epoch 7/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 42s 1s/step - accuracy: 0.7863 - loss: 0.5350 - val_accuracy: 0.8012 - val_loss: 0.4257 - learning_rate: 1.0000e-04
# Epoch 8/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 48s 1s/step - accuracy: 0.7631 - loss: 0.6580 - val_accuracy: 0.8071 - val_loss: 0.4245 - learning_rate: 1.0000e-04
# Epoch 9/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 48s 1s/step - accuracy: 0.8180 - loss: 0.5006 - val_accuracy: 0.8012 - val_loss: 0.4209 - learning_rate: 1.0000e-04
# Epoch 10/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 37s 862ms/step - accuracy: 0.7982 - loss: 0.4939 - val_accuracy: 0.8012 - val_loss: 0.4545 - learning_rate: 1.0000e-04
# Epoch 11/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 46s 1s/step - accuracy: 0.8105 - loss: 0.5128 - val_accuracy: 0.8220 - val_loss: 0.3808 - learning_rate: 1.0000e-04
# Epoch 12/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 62s 1s/step - accuracy: 0.8581 - loss: 0.4077 - val_accuracy: 0.8368 - val_loss: 0.3421 - learning_rate: 1.0000e-04
# Epoch 13/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 50s 1s/step - accuracy: 0.7917 - loss: 0.5172 - val_accuracy: 0.8398 - val_loss: 0.3651 - learning_rate: 1.0000e-04
# Epoch 14/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 55s 1s/step - accuracy: 0.8201 - loss: 0.4824 - val_accuracy: 0.8398 - val_loss: 0.3500 - learning_rate: 1.0000e-04
# Epoch 15/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 54s 1s/step - accuracy: 0.8169 - loss: 0.4533 - val_accuracy: 0.8338 - val_loss: 0.4056 - learning_rate: 1.0000e-04
# Epoch 16/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 38s 909ms/step - accuracy: 0.8478 - loss: 0.4211 - val_accuracy: 0.8398 - val_loss: 0.3689 - learning_rate: 2.0000e-05
# Epoch 17/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 39s 911ms/step - accuracy: 0.8569 - loss: 0.3835 - val_accuracy: 0.8398 - val_loss: 0.3567 - learning_rate: 2.0000e-05
# Epoch 18/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 31s 732ms/step - accuracy: 0.8636 - loss: 0.3524 - val_accuracy: 0.8487 - val_loss: 0.3537 - learning_rate: 2.0000e-05
# Epoch 19/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 32s 744ms/step - accuracy: 0.8479 - loss: 0.3994 - val_accuracy: 0.8427 - val_loss: 0.3481 - learning_rate: 4.0000e-06
# Epoch 20/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 37s 886ms/step - accuracy: 0.8462 - loss: 0.4106 - val_accuracy: 0.8457 - val_loss: 0.3483 - learning_rate: 4.0000e-06
# Epoch 21/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 43s 985ms/step - accuracy: 0.8405 - loss: 0.4389 - val_accuracy: 0.8487 - val_loss: 0.3505 - learning_rate: 4.0000e-06
# Epoch 22/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 41s 985ms/step - accuracy: 0.8412 - loss: 0.3851 - val_accuracy: 0.8487 - val_loss: 0.3500 - learning_rate: 1.0000e-06
# Epoch 23/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 33s 768ms/step - accuracy: 0.8507 - loss: 0.4091 - val_accuracy: 0.8487 - val_loss: 0.3499 - learning_rate: 1.0000e-06
# Epoch 24/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 32s 759ms/step - accuracy: 0.8547 - loss: 0.4030 - val_accuracy: 0.8457 - val_loss: 0.3494 - learning_rate: 1.0000e-06
# Epoch 25/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 30s 714ms/step - accuracy: 0.8371 - loss: 0.4199 - val_accuracy: 0.8487 - val_loss: 0.3491 - learning_rate: 1.0000e-06
# Epoch 26/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 36s 853ms/step - accuracy: 0.8591 - loss: 0.3800 - val_accuracy: 0.8487 - val_loss: 0.3477 - learning_rate: 1.0000e-06
# Epoch 27/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 47s 1s/step - accuracy: 0.8722 - loss: 0.3497 - val_accuracy: 0.8487 - val_loss: 0.3484 - learning_rate: 1.0000e-06
# Epoch 28/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 63s 1s/step - accuracy: 0.8479 - loss: 0.4359 - val_accuracy: 0.8487 - val_loss: 0.3488 - learning_rate: 1.0000e-06
# Epoch 29/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 42s 987ms/step - accuracy: 0.8464 - loss: 0.4147 - val_accuracy: 0.8487 - val_loss: 0.3490 - learning_rate: 1.0000e-06
# Epoch 30/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 38s 877ms/step - accuracy: 0.8531 - loss: 0.3743 - val_accuracy: 0.8487 - val_loss: 0.3482 - learning_rate: 1.0000e-06
# Epoch 31/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 35s 841ms/step - accuracy: 0.8397 - loss: 0.4280 - val_accuracy: 0.8487 - val_loss: 0.3482 - learning_rate: 1.0000e-06
# Epoch 32/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 35s 814ms/step - accuracy: 0.8309 - loss: 0.4497 - val_accuracy: 0.8487 - val_loss: 0.3471 - learning_rate: 1.0000e-06
# Epoch 33/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 36s 857ms/step - accuracy: 0.8457 - loss: 0.3809 - val_accuracy: 0.8487 - val_loss: 0.3459 - learning_rate: 1.0000e-06
# Epoch 34/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 29s 692ms/step - accuracy: 0.8416 - loss: 0.4057 - val_accuracy: 0.8487 - val_loss: 0.3467 - learning_rate: 1.0000e-06
# Epoch 35/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 22s 528ms/step - accuracy: 0.8338 - loss: 0.4288 - val_accuracy: 0.8487 - val_loss: 0.3461 - learning_rate: 1.0000e-06
# Epoch 36/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 22s 512ms/step - accuracy: 0.8346 - loss: 0.4178 - val_accuracy: 0.8487 - val_loss: 0.3454 - learning_rate: 1.0000e-06
# Epoch 37/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 23s 552ms/step - accuracy: 0.8670 - loss: 0.3504 - val_accuracy: 0.8487 - val_loss: 0.3455 - learning_rate: 1.0000e-06
# Epoch 38/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 27s 645ms/step - accuracy: 0.8551 - loss: 0.4050 - val_accuracy: 0.8487 - val_loss: 0.3446 - learning_rate: 1.0000e-06
# Epoch 39/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 26s 628ms/step - accuracy: 0.8437 - loss: 0.4035 - val_accuracy: 0.8487 - val_loss: 0.3462 - learning_rate: 1.0000e-06
# Epoch 40/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 26s 623ms/step - accuracy: 0.8525 - loss: 0.4321 - val_accuracy: 0.8487 - val_loss: 0.3458 - learning_rate: 1.0000e-06
# Epoch 41/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 26s 617ms/step - accuracy: 0.8449 - loss: 0.4234 - val_accuracy: 0.8487 - val_loss: 0.3434 - learning_rate: 1.0000e-06
# Epoch 42/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 26s 614ms/step - accuracy: 0.8597 - loss: 0.3629 - val_accuracy: 0.8487 - val_loss: 0.3433 - learning_rate: 1.0000e-06
# Epoch 43/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 25s 603ms/step - accuracy: 0.8410 - loss: 0.4107 - val_accuracy: 0.8487 - val_loss: 0.3431 - learning_rate: 1.0000e-06
# Epoch 44/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 25s 602ms/step - accuracy: 0.8491 - loss: 0.3883 - val_accuracy: 0.8487 - val_loss: 0.3439 - learning_rate: 1.0000e-06
# Epoch 45/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 26s 617ms/step - accuracy: 0.8551 - loss: 0.3929 - val_accuracy: 0.8487 - val_loss: 0.3446 - learning_rate: 1.0000e-06
# Epoch 46/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 26s 611ms/step - accuracy: 0.8499 - loss: 0.4385 - val_accuracy: 0.8487 - val_loss: 0.3438 - learning_rate: 1.0000e-06
# Epoch 47/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 26s 606ms/step - accuracy: 0.8380 - loss: 0.4257 - val_accuracy: 0.8487 - val_loss: 0.3443 - learning_rate: 1.0000e-06
# Epoch 48/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 31s 738ms/step - accuracy: 0.8485 - loss: 0.3826 - val_accuracy: 0.8487 - val_loss: 0.3424 - learning_rate: 1.0000e-06
# Epoch 49/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 34s 806ms/step - accuracy: 0.8253 - loss: 0.4615 - val_accuracy: 0.8457 - val_loss: 0.3416 - learning_rate: 1.0000e-06
# Epoch 50/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 32s 765ms/step - accuracy: 0.8412 - loss: 0.4175 - val_accuracy: 0.8487 - val_loss: 0.3427 - learning_rate: 1.0000e-06
# Epoch 51/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 32s 768ms/step - accuracy: 0.8449 - loss: 0.4329 - val_accuracy: 0.8487 - val_loss: 0.3437 - learning_rate: 1.0000e-06
# Epoch 52/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 32s 757ms/step - accuracy: 0.8301 - loss: 0.4324 - val_accuracy: 0.8487 - val_loss: 0.3427 - learning_rate: 1.0000e-06
# Epoch 53/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 32s 763ms/step - accuracy: 0.8397 - loss: 0.4311 - val_accuracy: 0.8487 - val_loss: 0.3441 - learning_rate: 1.0000e-06
# Epoch 54/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 30s 698ms/step - accuracy: 0.8578 - loss: 0.4255 - val_accuracy: 0.8487 - val_loss: 0.3430 - learning_rate: 1.0000e-06
# Epoch 55/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 27s 651ms/step - accuracy: 0.8605 - loss: 0.3721 - val_accuracy: 0.8487 - val_loss: 0.3430 - learning_rate: 1.0000e-06
# Epoch 56/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 27s 643ms/step - accuracy: 0.8599 - loss: 0.3855 - val_accuracy: 0.8487 - val_loss: 0.3424 - learning_rate: 1.0000e-06
# Epoch 57/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 28s 666ms/step - accuracy: 0.8484 - loss: 0.4218 - val_accuracy: 0.8457 - val_loss: 0.3430 - learning_rate: 1.0000e-06
# Epoch 58/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 41s 981ms/step - accuracy: 0.8404 - loss: 0.3788 - val_accuracy: 0.8457 - val_loss: 0.3427 - learning_rate: 1.0000e-06
# Epoch 59/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 49s 1s/step - accuracy: 0.8521 - loss: 0.4023 - val_accuracy: 0.8487 - val_loss: 0.3448 - learning_rate: 1.0000e-06
# Epoch 60/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 43s 1s/step - accuracy: 0.8663 - loss: 0.3681 - val_accuracy: 0.8487 - val_loss: 0.3442 - learning_rate: 1.0000e-06
# Epoch 61/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 58s 1s/step - accuracy: 0.8435 - loss: 0.4236 - val_accuracy: 0.8457 - val_loss: 0.3422 - learning_rate: 1.0000e-06
# Epoch 62/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 42s 978ms/step - accuracy: 0.8454 - loss: 0.3943 - val_accuracy: 0.8457 - val_loss: 0.3422 - learning_rate: 1.0000e-06
# Epoch 63/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 32s 766ms/step - accuracy: 0.8599 - loss: 0.3576 - val_accuracy: 0.8487 - val_loss: 0.3436 - learning_rate: 1.0000e-06
# Epoch 64/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 34s 817ms/step - accuracy: 0.8466 - loss: 0.3997 - val_accuracy: 0.8487 - val_loss: 0.3442 - learning_rate: 1.0000e-06
# Epoch 65/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 37s 890ms/step - accuracy: 0.8631 - loss: 0.3697 - val_accuracy: 0.8487 - val_loss: 0.3445 - learning_rate: 1.0000e-06
# Epoch 66/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 34s 815ms/step - accuracy: 0.8380 - loss: 0.4140 - val_accuracy: 0.8457 - val_loss: 0.3437 - learning_rate: 1.0000e-06
# Epoch 67/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 35s 827ms/step - accuracy: 0.8568 - loss: 0.3757 - val_accuracy: 0.8457 - val_loss: 0.3433 - learning_rate: 1.0000e-06
# Epoch 68/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 47s 1s/step - accuracy: 0.8365 - loss: 0.4396 - val_accuracy: 0.8457 - val_loss: 0.3428 - learning_rate: 1.0000e-06
# Epoch 69/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 46s 1s/step - accuracy: 0.8285 - loss: 0.4310 - val_accuracy: 0.8457 - val_loss: 0.3427 - learning_rate: 1.0000e-06
# Epoch 70/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 33s 785ms/step - accuracy: 0.8584 - loss: 0.3833 - val_accuracy: 0.8457 - val_loss: 0.3425 - learning_rate: 1.0000e-06
# Epoch 71/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 34s 806ms/step - accuracy: 0.8367 - loss: 0.4195 - val_accuracy: 0.8457 - val_loss: 0.3416 - learning_rate: 1.0000e-06
# Epoch 72/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 29s 688ms/step - accuracy: 0.8397 - loss: 0.4033 - val_accuracy: 0.8487 - val_loss: 0.3410 - learning_rate: 1.0000e-06
# Epoch 73/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 26s 612ms/step - accuracy: 0.8600 - loss: 0.3981 - val_accuracy: 0.8457 - val_loss: 0.3408 - learning_rate: 1.0000e-06
# Epoch 74/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 27s 652ms/step - accuracy: 0.8563 - loss: 0.3578 - val_accuracy: 0.8457 - val_loss: 0.3415 - learning_rate: 1.0000e-06
# Epoch 75/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 27s 637ms/step - accuracy: 0.8520 - loss: 0.3942 - val_accuracy: 0.8457 - val_loss: 0.3407 - learning_rate: 1.0000e-06
# Epoch 76/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 28s 670ms/step - accuracy: 0.8433 - loss: 0.4096 - val_accuracy: 0.8457 - val_loss: 0.3417 - learning_rate: 1.0000e-06
# Epoch 77/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 27s 631ms/step - accuracy: 0.8371 - loss: 0.4063 - val_accuracy: 0.8457 - val_loss: 0.3416 - learning_rate: 1.0000e-06
# Epoch 78/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 27s 635ms/step - accuracy: 0.8568 - loss: 0.3552 - val_accuracy: 0.8457 - val_loss: 0.3413 - learning_rate: 1.0000e-06
# Epoch 79/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 28s 653ms/step - accuracy: 0.8555 - loss: 0.4065 - val_accuracy: 0.8457 - val_loss: 0.3404 - learning_rate: 1.0000e-06
# Epoch 80/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 30s 716ms/step - accuracy: 0.8617 - loss: 0.3646 - val_accuracy: 0.8457 - val_loss: 0.3416 - learning_rate: 1.0000e-06
# Epoch 81/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 32s 757ms/step - accuracy: 0.8559 - loss: 0.4035 - val_accuracy: 0.8487 - val_loss: 0.3419 - learning_rate: 1.0000e-06
# Epoch 82/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 29s 696ms/step - accuracy: 0.8535 - loss: 0.4259 - val_accuracy: 0.8487 - val_loss: 0.3420 - learning_rate: 1.0000e-06
# Epoch 83/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 32s 729ms/step - accuracy: 0.8648 - loss: 0.3736 - val_accuracy: 0.8487 - val_loss: 0.3414 - learning_rate: 1.0000e-06
# Epoch 84/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 26s 616ms/step - accuracy: 0.8560 - loss: 0.3736 - val_accuracy: 0.8457 - val_loss: 0.3397 - learning_rate: 1.0000e-06
# Epoch 85/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 29s 702ms/step - accuracy: 0.8536 - loss: 0.3769 - val_accuracy: 0.8516 - val_loss: 0.3398 - learning_rate: 1.0000e-06
# Epoch 86/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 28s 657ms/step - accuracy: 0.8546 - loss: 0.3912 - val_accuracy: 0.8516 - val_loss: 0.3391 - learning_rate: 1.0000e-06
# Epoch 87/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 30s 711ms/step - accuracy: 0.8303 - loss: 0.4171 - val_accuracy: 0.8487 - val_loss: 0.3409 - learning_rate: 1.0000e-06
# Epoch 88/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 30s 704ms/step - accuracy: 0.8463 - loss: 0.4186 - val_accuracy: 0.8487 - val_loss: 0.3420 - learning_rate: 1.0000e-06
# Epoch 89/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 26s 611ms/step - accuracy: 0.8620 - loss: 0.3990 - val_accuracy: 0.8487 - val_loss: 0.3421 - learning_rate: 1.0000e-06
# Epoch 90/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 25s 597ms/step - accuracy: 0.8511 - loss: 0.3808 - val_accuracy: 0.8457 - val_loss: 0.3406 - learning_rate: 1.0000e-06
# Epoch 91/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 25s 589ms/step - accuracy: 0.8294 - loss: 0.4603 - val_accuracy: 0.8457 - val_loss: 0.3396 - learning_rate: 1.0000e-06
# Epoch 92/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 31s 746ms/step - accuracy: 0.8445 - loss: 0.3968 - val_accuracy: 0.8457 - val_loss: 0.3391 - learning_rate: 1.0000e-06
# Epoch 93/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 31s 717ms/step - accuracy: 0.8568 - loss: 0.3920 - val_accuracy: 0.8457 - val_loss: 0.3400 - learning_rate: 1.0000e-06
# Epoch 94/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 32s 761ms/step - accuracy: 0.8522 - loss: 0.4028 - val_accuracy: 0.8457 - val_loss: 0.3399 - learning_rate: 1.0000e-06
# Epoch 95/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 27s 629ms/step - accuracy: 0.8520 - loss: 0.3801 - val_accuracy: 0.8457 - val_loss: 0.3405 - learning_rate: 1.0000e-06
# Epoch 96/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 25s 594ms/step - accuracy: 0.8442 - loss: 0.4334 - val_accuracy: 0.8457 - val_loss: 0.3389 - learning_rate: 1.0000e-06
# Epoch 97/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 29s 690ms/step - accuracy: 0.8278 - loss: 0.4450 - val_accuracy: 0.8487 - val_loss: 0.3406 - learning_rate: 1.0000e-06
# Epoch 98/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 30s 709ms/step - accuracy: 0.8527 - loss: 0.4502 - val_accuracy: 0.8487 - val_loss: 0.3417 - learning_rate: 1.0000e-06
# Epoch 99/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 28s 656ms/step - accuracy: 0.8490 - loss: 0.3838 - val_accuracy: 0.8487 - val_loss: 0.3404 - learning_rate: 1.0000e-06
# Epoch 100/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 34s 813ms/step - accuracy: 0.8487 - loss: 0.3600 - val_accuracy: 0.8487 - val_loss: 0.3405 - learning_rate: 1.0000e-06
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 6s 589ms/step - accuracy: 0.8302 - loss: 0.3610
#
# ✅ Final Val Loss: 0.3405 | Val Accuracy: 0.8487
