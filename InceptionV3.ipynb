# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import (
    VGG16, ResNet50, InceptionV3, EfficientNetB0, DenseNet169
)
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten, Dense, Dropout, BatchNormalization, GlobalAveragePooling2D
from tensorflow.keras.callbacks import ReduceLROnPlateau

# 🔧 Enable Mac GPU acceleration if available
try:
    tf.config.experimental.list_physical_devices('GPU')
    print("✅ Mac GPU (M1/M2) Acceleration Enabled!")
except Exception as e:
    print("⚠️ GPU not available or not supported:", e)
data_dir = "/Users/amitabh/Documents/ML Work/Skin Cancer/v3/dataset"

# 🔧 CONFIG
classes = ["vasc", "df", "akeic"]
backbone_name = "InceptionV3"  # Choose: VGG16, ResNet50, InceptionV3, EfficientNetB0, DenseNet169
img_size = (224, 224) if backbone_name != "InceptionV3" else (299, 299)
batch_size = 32
epochs = 100
num_classes = len(classes)

# 🔄 Load and preprocess image data
X, y = [], []
for label, folder in enumerate(classes):
    folder_path = os.path.join(data_dir, folder)
    for img_file in os.listdir(folder_path):
        img_path = os.path.join(folder_path, img_file)
        try:
            img = tf.keras.utils.load_img(img_path, target_size=img_size)
            img_array = tf.keras.utils.img_to_array(img)
            X.append(img_array)
            y.append(label)
        except Exception as e:
            print(f"Skipped {img_path}: {e}")

X = np.array(X)
y = np.array(y)

X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.2, stratify=y, random_state=42)

# 🔄 Data Augmentation
train_gen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20, width_shift_range=0.1, height_shift_range=0.1,
    shear_range=0.1, zoom_range=0.1, horizontal_flip=True
)
val_gen = ImageDataGenerator(rescale=1./255)

train_data = train_gen.flow(X_train, y_train, batch_size=batch_size)
val_data = val_gen.flow(X_val, y_val, batch_size=batch_size)

# 🔌 Load chosen model
def get_backbone_model(name, input_shape):
    base = None
    if name == "VGG16":
        base = VGG16(weights="imagenet", include_top=False, input_shape=input_shape)
    elif name == "ResNet50":
        base = ResNet50(weights="imagenet", include_top=False, input_shape=input_shape)
    elif name == "InceptionV3":
        base = InceptionV3(weights="imagenet", include_top=False, input_shape=input_shape)
    elif name == "EfficientNetB0":
        base = EfficientNetB0(weights="imagenet", include_top=False, input_shape=input_shape)
    elif name == "DenseNet169":
        base = DenseNet169(weights="imagenet", include_top=False, input_shape=input_shape)
    else:
        raise ValueError("Unknown model name!")

    for layer in base.layers:
        layer.trainable = False

    return base

# 🧠 Build the model
input_shape = img_size + (3,)
base_model = get_backbone_model(backbone_name, input_shape)

model = Sequential([
    base_model,
    GlobalAveragePooling2D(),
    Dense(256, activation='relu'),
    BatchNormalization(),
    Dropout(0.5),
    Dense(num_classes, activation='softmax')
])

model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

print(f"🧠 Training with: {backbone_name}")
model.summary()

# 🚀 Train
history = model.fit(
    train_data,
    validation_data=val_data,
    epochs=epochs,
    callbacks=[ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=3, min_lr=1e-6)],
    verbose=1
)

# 📊 Evaluate
val_loss, val_acc = model.evaluate(val_data)
print(f"\n✅ Final Val Loss: {val_loss:.4f} | Val Accuracy: {val_acc:.4f}")

# 📈 Plot Accuracy and Loss
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Acc')
plt.plot(history.history['val_accuracy'], label='Val Acc')
plt.title('Accuracy')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.title('Loss')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# ✅ Mac GPU (M1/M2) Acceleration Enabled!
# 2025-07-28 15:39:56.718844: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M3
# 2025-07-28 15:39:56.719012: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 16.00 GB
# 2025-07-28 15:39:56.719015: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 5.33 GB
# 2025-07-28 15:39:56.719033: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2025-07-28 15:39:56.719052: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87910968/87910968 ━━━━━━━━━━━━━━━━━━━━ 11s 0us/step
# 🧠 Training with: InceptionV3
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ inception_v3 (Functional)       │ (None, 8, 8, 2048)     │    21,802,784 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 2048)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │       524,544 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_94          │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 3)              │           771 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 22,329,123 (85.18 MB)
#  Trainable params: 525,827 (2.01 MB)
#  Non-trainable params: 21,803,296 (83.17 MB)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/100
# 2025-07-28 15:40:11.990655: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:117] Plugin optimizer for device_type GPU is enabled.
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 23s 384ms/step - accuracy: 0.4504 - loss: 1.6134 - val_accuracy: 0.7240 - val_loss: 0.6981 - learning_rate: 1.0000e-04
# Epoch 2/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 14s 322ms/step - accuracy: 0.7049 - loss: 0.8369 - val_accuracy: 0.7685 - val_loss: 0.5835 - learning_rate: 1.0000e-04
# Epoch 3/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 362ms/step - accuracy: 0.7444 - loss: 0.7666 - val_accuracy: 0.7448 - val_loss: 0.5857 - learning_rate: 1.0000e-04
# Epoch 4/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 16s 381ms/step - accuracy: 0.7078 - loss: 0.7515 - val_accuracy: 0.7953 - val_loss: 0.4882 - learning_rate: 1.0000e-04
# Epoch 5/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 17s 392ms/step - accuracy: 0.7632 - loss: 0.6526 - val_accuracy: 0.7953 - val_loss: 0.4876 - learning_rate: 1.0000e-04
# Epoch 6/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 17s 408ms/step - accuracy: 0.7487 - loss: 0.6185 - val_accuracy: 0.8160 - val_loss: 0.4643 - learning_rate: 1.0000e-04
# Epoch 7/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 18s 432ms/step - accuracy: 0.7891 - loss: 0.5782 - val_accuracy: 0.7923 - val_loss: 0.4839 - learning_rate: 1.0000e-04
# Epoch 8/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 22s 518ms/step - accuracy: 0.8013 - loss: 0.5359 - val_accuracy: 0.8042 - val_loss: 0.4994 - learning_rate: 1.0000e-04
# Epoch 9/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 26s 607ms/step - accuracy: 0.7752 - loss: 0.6410 - val_accuracy: 0.7982 - val_loss: 0.4819 - learning_rate: 1.0000e-04
# Epoch 10/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 25s 589ms/step - accuracy: 0.8161 - loss: 0.5122 - val_accuracy: 0.8042 - val_loss: 0.4600 - learning_rate: 2.0000e-05
# Epoch 11/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 23s 541ms/step - accuracy: 0.8086 - loss: 0.5136 - val_accuracy: 0.8042 - val_loss: 0.4570 - learning_rate: 2.0000e-05
# Epoch 12/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 22s 528ms/step - accuracy: 0.7829 - loss: 0.5295 - val_accuracy: 0.8160 - val_loss: 0.4509 - learning_rate: 2.0000e-05
# Epoch 13/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 21s 497ms/step - accuracy: 0.8230 - loss: 0.4633 - val_accuracy: 0.8249 - val_loss: 0.4271 - learning_rate: 2.0000e-05
# Epoch 14/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 20s 465ms/step - accuracy: 0.8019 - loss: 0.5260 - val_accuracy: 0.8220 - val_loss: 0.4306 - learning_rate: 2.0000e-05
# Epoch 15/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 21s 498ms/step - accuracy: 0.8102 - loss: 0.4896 - val_accuracy: 0.8279 - val_loss: 0.4289 - learning_rate: 2.0000e-05
# Epoch 16/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 22s 533ms/step - accuracy: 0.8318 - loss: 0.4642 - val_accuracy: 0.8249 - val_loss: 0.4344 - learning_rate: 2.0000e-05
# Epoch 17/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 22s 519ms/step - accuracy: 0.8093 - loss: 0.5198 - val_accuracy: 0.8279 - val_loss: 0.4281 - learning_rate: 4.0000e-06
# Epoch 18/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 22s 532ms/step - accuracy: 0.8024 - loss: 0.4599 - val_accuracy: 0.8309 - val_loss: 0.4306 - learning_rate: 4.0000e-06
# Epoch 19/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 27s 647ms/step - accuracy: 0.8130 - loss: 0.5565 - val_accuracy: 0.8220 - val_loss: 0.4304 - learning_rate: 4.0000e-06
# Epoch 20/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 23s 556ms/step - accuracy: 0.8061 - loss: 0.4950 - val_accuracy: 0.8309 - val_loss: 0.4304 - learning_rate: 1.0000e-06
# Epoch 21/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 23s 549ms/step - accuracy: 0.8202 - loss: 0.5122 - val_accuracy: 0.8279 - val_loss: 0.4302 - learning_rate: 1.0000e-06
# Epoch 22/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 23s 539ms/step - accuracy: 0.8047 - loss: 0.4974 - val_accuracy: 0.8309 - val_loss: 0.4304 - learning_rate: 1.0000e-06
# Epoch 23/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 23s 538ms/step - accuracy: 0.8131 - loss: 0.4746 - val_accuracy: 0.8309 - val_loss: 0.4304 - learning_rate: 1.0000e-06
# Epoch 24/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 22s 534ms/step - accuracy: 0.8277 - loss: 0.4646 - val_accuracy: 0.8309 - val_loss: 0.4303 - learning_rate: 1.0000e-06
# Epoch 25/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 23s 555ms/step - accuracy: 0.8087 - loss: 0.5039 - val_accuracy: 0.8309 - val_loss: 0.4300 - learning_rate: 1.0000e-06
# Epoch 26/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 23s 555ms/step - accuracy: 0.8131 - loss: 0.5257 - val_accuracy: 0.8309 - val_loss: 0.4284 - learning_rate: 1.0000e-06
# Epoch 27/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 23s 540ms/step - accuracy: 0.8023 - loss: 0.5238 - val_accuracy: 0.8309 - val_loss: 0.4279 - learning_rate: 1.0000e-06
# Epoch 28/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 23s 536ms/step - accuracy: 0.7760 - loss: 0.5925 - val_accuracy: 0.8279 - val_loss: 0.4287 - learning_rate: 1.0000e-06
# Epoch 29/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 23s 544ms/step - accuracy: 0.8301 - loss: 0.4756 - val_accuracy: 0.8309 - val_loss: 0.4294 - learning_rate: 1.0000e-06
# Epoch 30/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 22s 521ms/step - accuracy: 0.7926 - loss: 0.5498 - val_accuracy: 0.8249 - val_loss: 0.4300 - learning_rate: 1.0000e-06
# Epoch 31/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 23s 539ms/step - accuracy: 0.8205 - loss: 0.5139 - val_accuracy: 0.8279 - val_loss: 0.4297 - learning_rate: 1.0000e-06
# Epoch 32/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 23s 539ms/step - accuracy: 0.8195 - loss: 0.4643 - val_accuracy: 0.8279 - val_loss: 0.4296 - learning_rate: 1.0000e-06
# Epoch 33/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 23s 540ms/step - accuracy: 0.8017 - loss: 0.5287 - val_accuracy: 0.8279 - val_loss: 0.4290 - learning_rate: 1.0000e-06
# Epoch 34/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 23s 554ms/step - accuracy: 0.8028 - loss: 0.5439 - val_accuracy: 0.8279 - val_loss: 0.4281 - learning_rate: 1.0000e-06
# Epoch 35/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 21s 502ms/step - accuracy: 0.7874 - loss: 0.5545 - val_accuracy: 0.8279 - val_loss: 0.4274 - learning_rate: 1.0000e-06
# Epoch 36/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 21s 494ms/step - accuracy: 0.8024 - loss: 0.5271 - val_accuracy: 0.8249 - val_loss: 0.4280 - learning_rate: 1.0000e-06
# Epoch 37/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 21s 493ms/step - accuracy: 0.7997 - loss: 0.5528 - val_accuracy: 0.8279 - val_loss: 0.4291 - learning_rate: 1.0000e-06
# Epoch 38/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 23s 555ms/step - accuracy: 0.8173 - loss: 0.4927 - val_accuracy: 0.8279 - val_loss: 0.4297 - learning_rate: 1.0000e-06
# Epoch 39/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 22s 526ms/step - accuracy: 0.8037 - loss: 0.5540 - val_accuracy: 0.8309 - val_loss: 0.4291 - learning_rate: 1.0000e-06
# Epoch 40/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 23s 539ms/step - accuracy: 0.8122 - loss: 0.5178 - val_accuracy: 0.8309 - val_loss: 0.4282 - learning_rate: 1.0000e-06
# Epoch 41/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 23s 537ms/step - accuracy: 0.7895 - loss: 0.5773 - val_accuracy: 0.8279 - val_loss: 0.4278 - learning_rate: 1.0000e-06
# Epoch 42/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 23s 533ms/step - accuracy: 0.8230 - loss: 0.4987 - val_accuracy: 0.8279 - val_loss: 0.4273 - learning_rate: 1.0000e-06
# Epoch 43/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 23s 540ms/step - accuracy: 0.7934 - loss: 0.5319 - val_accuracy: 0.8249 - val_loss: 0.4290 - learning_rate: 1.0000e-06
# Epoch 44/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 23s 556ms/step - accuracy: 0.8065 - loss: 0.5084 - val_accuracy: 0.8249 - val_loss: 0.4293 - learning_rate: 1.0000e-06
# Epoch 45/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 23s 545ms/step - accuracy: 0.8076 - loss: 0.4965 - val_accuracy: 0.8220 - val_loss: 0.4286 - learning_rate: 1.0000e-06
# Epoch 46/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 23s 552ms/step - accuracy: 0.8176 - loss: 0.4574 - val_accuracy: 0.8190 - val_loss: 0.4302 - learning_rate: 1.0000e-06
# Epoch 47/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 23s 548ms/step - accuracy: 0.8167 - loss: 0.4654 - val_accuracy: 0.8220 - val_loss: 0.4299 - learning_rate: 1.0000e-06
# Epoch 48/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 21s 493ms/step - accuracy: 0.8057 - loss: 0.4839 - val_accuracy: 0.8279 - val_loss: 0.4283 - learning_rate: 1.0000e-06
# Epoch 49/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 22s 507ms/step - accuracy: 0.7957 - loss: 0.5580 - val_accuracy: 0.8279 - val_loss: 0.4281 - learning_rate: 1.0000e-06
# Epoch 50/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 25s 600ms/step - accuracy: 0.8053 - loss: 0.5328 - val_accuracy: 0.8249 - val_loss: 0.4284 - learning_rate: 1.0000e-06
# Epoch 51/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 24s 568ms/step - accuracy: 0.8310 - loss: 0.4807 - val_accuracy: 0.8249 - val_loss: 0.4287 - learning_rate: 1.0000e-06
# Epoch 52/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 25s 583ms/step - accuracy: 0.7880 - loss: 0.5906 - val_accuracy: 0.8279 - val_loss: 0.4280 - learning_rate: 1.0000e-06
# Epoch 53/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 23s 546ms/step - accuracy: 0.7888 - loss: 0.5476 - val_accuracy: 0.8220 - val_loss: 0.4282 - learning_rate: 1.0000e-06
# Epoch 54/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 22s 527ms/step - accuracy: 0.7920 - loss: 0.5201 - val_accuracy: 0.8249 - val_loss: 0.4285 - learning_rate: 1.0000e-06
# Epoch 55/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 22s 532ms/step - accuracy: 0.7794 - loss: 0.5684 - val_accuracy: 0.8249 - val_loss: 0.4294 - learning_rate: 1.0000e-06
# Epoch 56/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 22s 530ms/step - accuracy: 0.8137 - loss: 0.5096 - val_accuracy: 0.8279 - val_loss: 0.4301 - learning_rate: 1.0000e-06
# Epoch 57/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 28s 678ms/step - accuracy: 0.8168 - loss: 0.4717 - val_accuracy: 0.8190 - val_loss: 0.4297 - learning_rate: 1.0000e-06
# Epoch 58/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 27s 649ms/step - accuracy: 0.7955 - loss: 0.5100 - val_accuracy: 0.8220 - val_loss: 0.4297 - learning_rate: 1.0000e-06
# Epoch 59/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 24s 565ms/step - accuracy: 0.8302 - loss: 0.5193 - val_accuracy: 0.8190 - val_loss: 0.4296 - learning_rate: 1.0000e-06
# Epoch 60/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 26s 628ms/step - accuracy: 0.8015 - loss: 0.4610 - val_accuracy: 0.8190 - val_loss: 0.4290 - learning_rate: 1.0000e-06
# Epoch 61/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 28s 676ms/step - accuracy: 0.8019 - loss: 0.5340 - val_accuracy: 0.8190 - val_loss: 0.4305 - learning_rate: 1.0000e-06
# Epoch 62/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 27s 643ms/step - accuracy: 0.7887 - loss: 0.5387 - val_accuracy: 0.8249 - val_loss: 0.4292 - learning_rate: 1.0000e-06
# Epoch 63/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 26s 603ms/step - accuracy: 0.7974 - loss: 0.5282 - val_accuracy: 0.8249 - val_loss: 0.4294 - learning_rate: 1.0000e-06
# Epoch 64/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 22s 509ms/step - accuracy: 0.8010 - loss: 0.5013 - val_accuracy: 0.8220 - val_loss: 0.4297 - learning_rate: 1.0000e-06
# Epoch 65/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 21s 505ms/step - accuracy: 0.8296 - loss: 0.4892 - val_accuracy: 0.8279 - val_loss: 0.4295 - learning_rate: 1.0000e-06
# Epoch 66/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 21s 496ms/step - accuracy: 0.7895 - loss: 0.5333 - val_accuracy: 0.8249 - val_loss: 0.4287 - learning_rate: 1.0000e-06
# Epoch 67/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 21s 502ms/step - accuracy: 0.8047 - loss: 0.5026 - val_accuracy: 0.8220 - val_loss: 0.4287 - learning_rate: 1.0000e-06
# Epoch 68/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 21s 505ms/step - accuracy: 0.8048 - loss: 0.4857 - val_accuracy: 0.8249 - val_loss: 0.4304 - learning_rate: 1.0000e-06
# Epoch 69/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 21s 505ms/step - accuracy: 0.8011 - loss: 0.5312 - val_accuracy: 0.8249 - val_loss: 0.4290 - learning_rate: 1.0000e-06
# Epoch 70/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 21s 508ms/step - accuracy: 0.8031 - loss: 0.5354 - val_accuracy: 0.8279 - val_loss: 0.4281 - learning_rate: 1.0000e-06
# Epoch 71/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 20s 476ms/step - accuracy: 0.7993 - loss: 0.5180 - val_accuracy: 0.8249 - val_loss: 0.4291 - learning_rate: 1.0000e-06
# Epoch 72/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 24s 561ms/step - accuracy: 0.8031 - loss: 0.5094 - val_accuracy: 0.8249 - val_loss: 0.4299 - learning_rate: 1.0000e-06
# Epoch 73/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 24s 556ms/step - accuracy: 0.8189 - loss: 0.4928 - val_accuracy: 0.8279 - val_loss: 0.4274 - learning_rate: 1.0000e-06
# Epoch 74/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 22s 513ms/step - accuracy: 0.8232 - loss: 0.4994 - val_accuracy: 0.8279 - val_loss: 0.4277 - learning_rate: 1.0000e-06
# Epoch 75/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 16s 376ms/step - accuracy: 0.8181 - loss: 0.4730 - val_accuracy: 0.8309 - val_loss: 0.4269 - learning_rate: 1.0000e-06
# Epoch 76/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 16s 385ms/step - accuracy: 0.8043 - loss: 0.5782 - val_accuracy: 0.8309 - val_loss: 0.4265 - learning_rate: 1.0000e-06
# Epoch 77/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 17s 405ms/step - accuracy: 0.7987 - loss: 0.4927 - val_accuracy: 0.8309 - val_loss: 0.4275 - learning_rate: 1.0000e-06
# Epoch 78/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 195s 5s/step - accuracy: 0.8099 - loss: 0.4705 - val_accuracy: 0.8279 - val_loss: 0.4266 - learning_rate: 1.0000e-06
# Epoch 79/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1106s 27s/step - accuracy: 0.8141 - loss: 0.4770 - val_accuracy: 0.8279 - val_loss: 0.4268 - learning_rate: 1.0000e-06
# Epoch 80/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 256s 6s/step - accuracy: 0.8330 - loss: 0.4606 - val_accuracy: 0.8249 - val_loss: 0.4262 - learning_rate: 1.0000e-06
# Epoch 81/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 14s 322ms/step - accuracy: 0.7990 - loss: 0.5682 - val_accuracy: 0.8279 - val_loss: 0.4260 - learning_rate: 1.0000e-06
# Epoch 82/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 351ms/step - accuracy: 0.8275 - loss: 0.4374 - val_accuracy: 0.8249 - val_loss: 0.4261 - learning_rate: 1.0000e-06
# Epoch 83/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 16s 382ms/step - accuracy: 0.7902 - loss: 0.5189 - val_accuracy: 0.8279 - val_loss: 0.4268 - learning_rate: 1.0000e-06
# Epoch 84/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 17s 403ms/step - accuracy: 0.7964 - loss: 0.5165 - val_accuracy: 0.8249 - val_loss: 0.4256 - learning_rate: 1.0000e-06
# Epoch 85/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 18s 424ms/step - accuracy: 0.7721 - loss: 0.5468 - val_accuracy: 0.8279 - val_loss: 0.4259 - learning_rate: 1.0000e-06
# Epoch 86/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 20s 474ms/step - accuracy: 0.8063 - loss: 0.5230 - val_accuracy: 0.8309 - val_loss: 0.4261 - learning_rate: 1.0000e-06
# Epoch 87/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 29s 686ms/step - accuracy: 0.8106 - loss: 0.5290 - val_accuracy: 0.8220 - val_loss: 0.4277 - learning_rate: 1.0000e-06
# Epoch 88/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 32s 761ms/step - accuracy: 0.8001 - loss: 0.5316 - val_accuracy: 0.8249 - val_loss: 0.4271 - learning_rate: 1.0000e-06
# Epoch 89/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 25s 595ms/step - accuracy: 0.7980 - loss: 0.5343 - val_accuracy: 0.8279 - val_loss: 0.4270 - learning_rate: 1.0000e-06
# Epoch 90/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 23s 554ms/step - accuracy: 0.7980 - loss: 0.5409 - val_accuracy: 0.8279 - val_loss: 0.4262 - learning_rate: 1.0000e-06
# Epoch 91/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 25s 589ms/step - accuracy: 0.8177 - loss: 0.4763 - val_accuracy: 0.8279 - val_loss: 0.4258 - learning_rate: 1.0000e-06
# Epoch 92/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 23s 542ms/step - accuracy: 0.8183 - loss: 0.5183 - val_accuracy: 0.8279 - val_loss: 0.4262 - learning_rate: 1.0000e-06
# Epoch 93/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 28s 679ms/step - accuracy: 0.8113 - loss: 0.4898 - val_accuracy: 0.8279 - val_loss: 0.4263 - learning_rate: 1.0000e-06
# Epoch 94/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 34s 817ms/step - accuracy: 0.8261 - loss: 0.4844 - val_accuracy: 0.8279 - val_loss: 0.4257 - learning_rate: 1.0000e-06
# Epoch 95/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 38s 893ms/step - accuracy: 0.7911 - loss: 0.5456 - val_accuracy: 0.8279 - val_loss: 0.4262 - learning_rate: 1.0000e-06
# Epoch 96/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 32s 759ms/step - accuracy: 0.8075 - loss: 0.4939 - val_accuracy: 0.8309 - val_loss: 0.4261 - learning_rate: 1.0000e-06
# Epoch 97/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 31s 724ms/step - accuracy: 0.8160 - loss: 0.5053 - val_accuracy: 0.8279 - val_loss: 0.4254 - learning_rate: 1.0000e-06
# Epoch 98/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 33s 786ms/step - accuracy: 0.8270 - loss: 0.4623 - val_accuracy: 0.8279 - val_loss: 0.4251 - learning_rate: 1.0000e-06
# Epoch 99/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 35s 841ms/step - accuracy: 0.8051 - loss: 0.5473 - val_accuracy: 0.8309 - val_loss: 0.4259 - learning_rate: 1.0000e-06
# Epoch 100/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 54s 1s/step - accuracy: 0.8384 - loss: 0.4564 - val_accuracy: 0.8309 - val_loss: 0.4260 - learning_rate: 1.0000e-06
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 738ms/step - accuracy: 0.8305 - loss: 0.4124
#
# ✅ Final Val Loss: 0.4260 | Val Accuracy: 0.8309
